# %% [markdown]
# # Get a List of the Most Recommended Books

# %%
from bs4 import BeautifulSoup as bs
import requests

# %% [markdown]
# https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read

# %%
link = "https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"

# %%
def show_html(link):
    #returns a string object
    soup = bs(requests.get(link).text, 'html.parser')
    for js in soup('script'):
        js.decompose()     
    return soup.prettify()

# %%
print(show_html(link))
# Out:
# <!DOCTYPE html>
# <!--[if IE 7]>
# <html class="ie ie7" lang="en-US" class="no-js">
# <![endif]-->
# <!--[if IE 8]>
# <html class="ie ie8" lang="en-US" class="no-js">
# <![endif]-->
# <!--[if !(IE 7) | !(IE 8) ]><!-->
# <html class="no-js" lang="en-US">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="initial-scale=1,width=device-width,height=device-height" name="viewport">
#    <meta content="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read" property="og:url"/>
#    <meta content="PenguinRandomhouse.com" property="og:site_name"/>
#    <meta content="356679881167712" property="fb:app_id"/>
#    <meta content="summary" name="twitter:card"/>
#    <meta content="@penguinrandomhouse" name="twitter:site"/>
#    <title>
#     21 Books You've Been Meaning To Read | Penguin Random House
#    </title>
#    <meta content="21 Books You've Been Meaning To Read | Penguin Random House" itemprop="name"/>
#    <meta content="21 Books You've Been Meaning To Read | Penguin Random House" property="og:title"/>
#    <meta content="21 Books You've Been Meaning To Read | Penguin Random House" name="twitter:title"/>
#    <meta content="13673457388" property="fb:pages"/>
#    <meta content="Reading lists begin as a shelf full of hope until the year flies by, and you find yourself flooded with procrastination. Cheers to the books we've..." name="description"/>
#    <meta content="Reading lists begin as a shelf full of hope until the year flies by, and you find yourself flooded with procrastination. Cheers to the books we've been meaning to read all these years and should probably..." itemprop="description"/>
#    <meta content="Reading lists begin as a shelf full of hope until the year flies by, and you find yourself flooded with procrastination. Cheers to the books we've been meaning to read all these years and should probably..." property="og:description"/>
#    <meta content="Reading lists begin as a shelf full of hope until the year flies by, and you find yourself flooded with procrastination. Cheers to the books we've been meaning to read all these years and..." name="twitter:description"/>
#    <meta content="https://assets.penguinrandomhouse.com/the-read-down-images/list-4453-triad.png" itemprop="image"/>
#    <meta content="https://assets.penguinrandomhouse.com/the-read-down-images/list-4453-triad.png" property="og:image"/>
#    <meta content="https://assets.penguinrandomhouse.com/the-read-down-images/list-4453-triad.png" name="twitter:image"/>
#    <meta content="article" property="og:type"/>
#    <!--[if lt IE 9]>
# 	<script src="https://www.penguinrandomhouse.com/wp-content/themes/penguinrandomhouse/js/ie.min.js"></script>
# 	<![endif]-->
#    <!--[if IE 9]>
# 		<link rel='stylesheet' id='global-ie9-css' href='/wp-content/themes/penguinrandomhouse/css/ie9.min.css' type='text/css' media='all' />
# 	<![endif]-->
#    <style>
#     html.fouc-factor{ opacity:0; filter:alpha(opacity=0); }
#    </style>
#    <link href="//ajax.googleapis.com" rel="dns-prefetch"/>
#    <link href="//s.w.org" rel="dns-prefetch"/>
#    <link href="https://www.penguinrandomhouse.com/wp-includes/css/dist/block-library/style.min.css?ver=5.1.1" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
#    <link href="https://www.penguinrandomhouse.com/wp-content/themes/penguinrandomhouse/style.css?ver=cb20200402095937" id="twentyfourteen-style-css" media="all" rel="stylesheet" type="text/css"/>
#    <!--[if lt IE 9]>
# <link rel='stylesheet' id='twentyfourteen-ie-css'  href='https://www.penguinrandomhouse.com/wp-content/themes/penguinrandomhouse/css/ie.css?ver=cb20200402095937' type='text/css' media='all' />
# <![endif]-->
#    <link href="https://www.penguinrandomhouse.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.penguinrandomhouse.com%2Fthe-read-down%2F21-books-youve-been-meaning-to-read" rel="alternate" type="application/json+oembed"/>
#    <link href="https://www.penguinrandomhouse.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.penguinrandomhouse.com%2Fthe-read-down%2F21-books-youve-been-meaning-to-read&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
#    <link href="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read" rel="canonical"/>
#    <style type="text/css">
#     .recentcomments a{display:inline !important;padding:0 !important;margin:0 !important;}
#    </style>
#    <!-- WP_Route:  the_read_down -->
#    <link href="https://www.penguinrandomhouse.com/wp-content/themes/penguinrandomhouse/css/list.min.css?vers=cb20200402095937" media="all" rel="stylesheet"/>
#    <noscript>
#     <link href="/wp-content/themes/penguinrandomhouse/styles-nojs.min.css" id="no-js-global-css" media="all" rel="stylesheet" type="text/css"/>
#    </noscript>
#    <link href="/wp-content/themes/penguinrandomhouse/styles-print.min.css" id="global-print-css" media="print" rel="stylesheet" type="text/css"/>
#   </meta>
#  </head>
#  <body class="wp_router_page-template-default single single-wp_router_page postid-5 wp-embed-responsive group-blog masthead-fixed full-width singular">
#   <!-- Start Tealium tag -->
#   <!-- / End Tealium tag -->
#   <div id="exit_int_post">
#    <div class="before_link">
#     Before you go...
#    </div>
#    <div class="line1">
#     Check Out
#    </div>
#    <div class="line2">
#     The Bestselling Books of All Time
#    </div>
#    <a class="ei_link" href="/the-read-down/the-bestselling-books-of-all-time/">
#     See the List
#    </a>
#   </div>
#   <div class="container">
#    <div class="row">
#     <header class="main-header">
#      <!-- Start Mobile Header -->
#      <div class="mobile hidden-sm hidden-md hidden-lg">
#       <div class="mobile-nav notransition" id="mobile-nav">
#        <form action="/search/site" class="mobile-search-form" method="get" role="search">
#         <div class="search-box" id="mobile-searchbox">
#          <div class="search-controls">
#           <input autocomplete="off" class="search-field" data-original-title="" id="search-box" name="q" placeholder="SEARCH" title="" type="search" value=""/>
#           <input class="search-submit" type="submit" value=""/>
#          </div>
#         </div>
#        </form>
#        <a class="logo" href="/">
#         <img alt="Penguin Random House" border="0" height="30" src="https://www.penguinrandomhouse.com/wp-content/themes/penguinrandomhouse/images/penguin-random-house-logo-square.png"/>
#        </a>
#        <a class="cart" href="https://cart.penguinrandomhouse.com/cart.php">
#         <i class="fa fa-shopping-cart">
#         </i>
#         <div class="circle">
#          <div class="item-count">
#           2
#          </div>
#         </div>
#        </a>
#       </div>
#      </div>
#      <!-- / End Mobile Header -->
#      <!-- Start Desktop Header -->
#      <div class="desktop container">
#       <div class="row">
#        <div class="logo hidden-xs">
#         <a href="/">
#          <img alt="Penguin Random House" src="https://www.penguinrandomhouse.com/wp-content/themes/penguinrandomhouse/images/prh-logo.png"/>
#         </a>
#        </div>
#        <div class="toolbar-nav" id="toolbar-nav">
#         <div class="social" id="social-nav">
#         </div>
#         <div class="cart hidden-xs">
#          <a href="https://cart.penguinrandomhouse.com/cart.php">
#           Cart:
#           <i class="fa fa-shopping-cart">
#           </i>
#          </a>
#          <span class="item-count">
#           12
#          </span>
#         </div>
#        </div>
#       </div>
#       <div class="main-nav">
#        <nav id="main-nav" role="navigation">
#         <ul>
#          <li>
#           <a class="nav-books" href="/books/">
#            Books
#           </a>
#          </li>
#          <li>
#           <a class="nav-authors" href="/authors/">
#            Authors
#           </a>
#          </li>
#          <li>
#           <a class="nav-blog" href="/series/">
#            Series
#           </a>
#          </li>
#          <li>
#           <a class="nav-aboutus" href="/about-us/">
#            About Us
#           </a>
#          </li>
#          <li class="search-box">
#           <form action="/search/site" class="search-form" id="seachformglobal" method="get" role="search">
#            <div class="search-controls">
#             <input autocomplete="off" class="search-field" id="search-box" name="q" placeholder="SEARCH BY TITLE, AUTHOR, OR KEYWORD" type="search" value="">
#              <input class="search-submit" type="submit" value="">
#              </input>
#             </input>
#            </div>
#           </form>
#          </li>
#         </ul>
#        </nav>
#       </div>
#      </div>
#      <!-- / End Desktop Header -->
#     </header>
#    </div>
#   </div>
#   <!-- container END -->
#   <!-- Start Main Page Wrap -->
#   <div class="page-wrap notransition" id="main">
#    <!-- Start Mobile Sidebar -->
#    <div class="side-nav notransition" id="side-nav">
#     <img alt="Penguin Random House" border="0" class="logo" height="49" src="https://www.penguinrandomhouse.com/wp-content/themes/penguinrandomhouse/images/prh-logo-sm.png" width="100"/>
#    </div>
#    <!-- / End Mobile Sidebar -->
#    <div class="mq-view">
#    </div>
#    <div class="tmpl-list" id="tmpl-indc">
#    </div>
#    <section class="inner-facade list-awesome hero">
#     <div class="readdown-desktop-banner" style="background-color: #ffffff;">
#      <img src="https://assets.penguinrandomhouse.com/wp-content/uploads/2016/01/13115358/List-Header-MeaningtoRead-1400x380-glasses.jpg">
#      </img>
#     </div>
#     <div class="readdown-mobile-banner">
#      <img src="https://assets.penguinrandomhouse.com/wp-content/uploads/2016/01/13115403/List-Header-MeaningtoRead-770x456-glasses.jpg"/>
#     </div>
#     <div class="container">
#      <!-- Start Scaffolding -->
#      <div class="scaffolding row">
#       <div class="col-xs-1 col-sm-0 col-md-0 col-lg-0">
#       </div>
#       <div class="main-content col-xs-14 col-sm-16 col-md-16 col-lg-16">
#        <div class="centered">
#         <span>
#          The ReadDown
#         </span>
#         <h1>
#          21 Books You’ve Been Meaning To Read
#         </h1>
#        </div>
#        <article>
#         <p style="text-align: center;">
#          Reading lists begin as a shelf full of hope until the year flies by, and you find yourself flooded with procrastination. Cheers to the books we’ve been meaning to read all these years and should probably start at some point.
#         </p>
#        </article>
#       </div>
#       <!-- main-content -->
#       <div class="col-xs-1 col-sm-0 col-md-0 col-lg-0">
#       </div>
#      </div>
#      <!-- scaffolding row -->
#     </div>
#     <!-- container -->
#    </section>
#    <ol class="awesome-list">
#     <li authid="31231" author="Leo Tolstoy" cat-data="Literary Fiction | Fiction Classics | Historical Fiction" class="inner-facade" data-ebook="9780307806581" data-format="Paperback" data-format-name="Paperback" data-isbn="9781400079988" format-data="Paperback,Ebook" id="book1" imprint-data="Vintage" isbn="9781400079988" ttl="War and Peace" workid="208646">
#      <div class="container relative">
#       <div class="list-number">
#        <span>
#         1
#        </span>
#       </div>
#       <div class="list-meta-wrap">
#        <div class="list-meta seemoreenable">
#         <div class="readdown-cover-wrap-desktop" href="/books/208646/war-and-peace-by-leo-tolstoy-a-new-translation-by-richard-pevear-and-larissa-volokhonsky/">
#          <div class="three-d">
#           <div class="cover">
#            <span class="">
#             <img alt="War and Peace Book Cover Picture" class="img-responsive" src="https://images4.penguinrandomhouse.com/cover/9781400079988"/>
#            </span>
#            <div class="cover__backcover-container">
#             <img alt="War and Peace Book Cover Picture" class="cover__backcover" src="https://images4.penguinrandomhouse.com/cover/9781400079988"/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <h2>
#          <a href="/books/208646/war-and-peace-by-leo-tolstoy-a-new-translation-by-richard-pevear-and-larissa-volokhonsky/">
#           War and Peace
#          </a>
#         </h2>
#         <h2 class="author">
#          by Leo Tolstoy
#         </h2>
#         <div class="desc">
#          A legendary masterpiece, this book is synonymous with difficult reading, so why not challenge yourshelf.
#         </div>
#         <div class="readdown-cover-wrap-mobile" href="/books/208646/war-and-peace-by-leo-tolstoy-a-new-translation-by-richard-pevear-and-larissa-volokhonsky/">
#          <div class="three-d">
#           <div class="cover">
#            <span class="">
#             <img alt="War and Peace Book Cover Picture" class="img-responsive" src="https://images4.penguinrandomhouse.com/cover/9781400079988"/>
#            </span>
#            <div class="cover__backcover-container">
#             <img alt="War and Peace Book Cover Picture" class="cover__backcover" src="https://images4.penguinrandomhouse.com/cover/9781400079988"/>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="buy">
#        <div class="buy_clmn buy_small">
#         <h3>
#          Paperback
#          <div class="buy-price">
#           $20.00
#          </div>
#         </h3>
#         <div class="cart-bttns">
#          <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
#           <button type="submit">
#            Add to cart
#           </button>
#           <input id="itemISBN" name="itemISBN" type="hidden" value="9781400079988"/>
#           <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
#           <input id="siteName" name="siteName" type="hidden" value="prh"/>
#           <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
#           <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
#           <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
#          </form>
#         </div>
#        </div>
#        <div class="buy_clmn">
#         <div class="ajax-wait hidden">
#         </div>
#         <h3>
#          Also available from:
#         </h3>
#         <a class="btn buy hidden" rel="popover">
#          Buy
#         </a>
#         <div class="hidden parking-lot 9781400079988 by_work amazonlast">
#         </div>
#        </div>
#       </div>
#      </div>
#     </li>
#     <li authid="21332" author="Toni Morrison" cat-data="Literary Fiction" class="inner-facade no-bg-el" data-ebook="9780307388124" data-format="Paperback" data-format-name="Paperback" data-isbn="9781400033423" format-data="Paperback,Hardcover,Ebook,Audio" id="book2" imprint-data="Vintage" isbn="9781400033423" ttl="Song of Solomon" workid="117657">
#      <div class="container relative">
#       <div class="list-number">
#        <span>
#         2
#        </span>
#       </div>
#       <div class="list-meta-wrap">
#        <div class="list-meta seemoreenable">
#         <div class="readdown-cover-wrap-desktop" href="/books/117657/song-of-solomon-by-toni-morrison/">
#          <div class="three-d">
#           <div class="cover">
#            <span class="">
#             <img alt="Song of Solomon Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9781400033423" src=""/>
#            </span>
#            <div class="cover__backcover-container">
#             <img alt="Song of Solomon Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9781400033423" src=""/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <h2>
#          <a href="/books/117657/song-of-solomon-by-toni-morrison/">
#           Song of Solomon
#          </a>
#         </h2>
#         <h2 class="author">
#          by Toni Morrison
#         </h2>
#         <div class="desc">
#          One must always read a novel by this Nobel Prize winning author.
#         </div>
#         <div class="readdown-cover-wrap-mobile" href="/books/117657/song-of-solomon-by-toni-morrison/">
#          <div class="three-d">
#           <div class="cover">
#            <span class="">
#             <img alt="Song of Solomon Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9781400033423" src=""/>
#            </span>
#            <div class="cover__backcover-container">
#             <img alt="Song of Solomon Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9781400033423" src=""/>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="buy">
#        <div class="buy_clmn buy_small">
#         <h3>
#          Paperback
#          <div class="buy-price">
#           $16.00
#          </div>
#         </h3>
#         <div class="cart-bttns">
#          <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
#           <button type="submit">
#            Add to cart
#           </button>
#           <input id="itemISBN" name="itemISBN" type="hidden" value="9781400033423"/>
#           <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
#           <input id="siteName" name="siteName" type="hidden" value="prh"/>
#           <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
#           <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
#           <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
#          </form>
#         </div>
#        </div>
#        <div class="buy_clmn">
#         <div class="ajax-wait hidden">
#         </div>
#         <h3>
#          Also available from:
#         </h3>
#         <a class="btn buy hidden" rel="popover">
#          Buy
#         </a>
#         <div class="hidden parking-lot 9781400033423 by_work amazonlast">
#         </div>
#        </div>
#       </div>
#      </div>
#     </li>
#     <li authid="14876" author="James Joyce" cat-data="Fiction Classics | Literary Fiction" class="inner-facade no-bg-el" data-format="Paperback" data-format-name="Paperback" data-isbn="9780679722762" format-data="Paperback,Hardcover,Ebook" id="book3" imprint-data="Everyman's Library" isbn="9780679722762" ttl="Ulysses" workid="88933">
#      <div class="container relative">
#       <div class="list-number">
#        <span>
#         3
#        </span>
#       </div>
#       <div class="list-meta-wrap">
#        <div class="list-meta seemoreenable">
#         <div class="readdown-cover-wrap-desktop" href="/books/88933/ulysses-by-james-joyce/9780679722762/">
#          <div class="three-d">
#           <div class="cover">
#            <span class="">
#             <img alt="Ulysses Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780679722762" src=""/>
#            </span>
#            <div class="cover__backcover-container">
#             <img alt="Ulysses Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780679722762" src=""/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <h2>
#          <a href="/books/88933/ulysses-by-james-joyce/9780679722762/">
#           Ulysses
#          </a>
#         </h2>
#         <h2 class="author">
#          by James Joyce
#         </h2>
#         <div class="desc">
#          “Joyce’s parallel use of
#          <em>
#           The Odyssey
#          </em>
#          …has the importance of a scientific discovery…” –T. S. Eliot
#         </div>
#         <div class="readdown-cover-wrap-mobile" href="/books/88933/ulysses-by-james-joyce/9780679722762/">
#          <div class="three-d">
#           <div class="cover">
#            <span class="">
#             <img alt="Ulysses Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780679722762" src=""/>
#            </span>
#            <div class="cover__backcover-container">
#             <img alt="Ulysses Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780679722762" src=""/>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="buy">
#        <div class="buy_clmn buy_small">
#         <h3>
#          Paperback
#          <div class="buy-price">
#           $17.00
#          </div>
#         </h3>
#         <div class="cart-bttns">
#          <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
#           <button type="submit">
#            Add to cart
#           </button>
#           <input id="itemISBN" name="itemISBN" type="hidden" value="9780679722762"/>
#           <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
#           <input id="siteName" name="siteName" type="hidden" value="prh"/>
#           <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
#           <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
#           <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
#          </form>
#         </div>
#        </div>
#        <div class="buy_clmn">
#         <div class="ajax-wait hidden">
#         </div>
#         <h3>
#          Also available from:
#         </h3>
#         <a class="btn buy hidden" rel="popover">
#          Buy
#         </a>
#         <div class="hidden parking-lot 9780679722762 by_isbn amazonlast">
#         </div>
#        </div>
#       </div>
#      </div>
#     </li>
#     <li authid="52439,227771" author="Carlos Ruiz Zafon,Jessica Hische" cat-data="Literary Fiction | Suspense &amp; Thriller" class="inner-facade no-bg-el" data-ebook="9781101147061" data-format="Hardcover" data-format-name="Hardcover" data-isbn="9780143126393" format-data="Paperback,Hardcover,Ebook,Audio" id="book4" imprint-data="Penguin Books" isbn="9780143126393" ttl="The Shadow of the Wind" workid="292766">
#      <div class="container relative">
#       <div class="list-number">
#        <span>
#         4
#        </span>
#       </div>
#       <div class="list-meta-wrap">
#        <div class="list-meta seemoreenable">
#         <div class="readdown-cover-wrap-desktop" href="/books/292766/the-shadow-of-the-wind-by-carlos-ruiz-zafon/">
#          <div class="three-d">
#           <div class="cover">
#            <span class="">
#             <img alt="The Shadow of the Wind Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780143126393" src=""/>
#            </span>
#            <div class="cover__backcover-container">
#             <img alt="The Shadow of the Wind Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780143126393" src=""/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <h2>
#          <a href="/books/292766/the-shadow-of-the-wind-by-carlos-ruiz-zafon/">
#           The Shadow of the Wind
#          </a>
#         </h2>
#         <h2 class="author">
#          by Carlos Ruiz Zafon
#         </h2>
#         <div class="desc">
#          An incredible book by a beloved writer is a must read.
#         </div>
#         <div class="readdown-cover-wrap-mobile" href="/books/292766/the-shadow-of-the-wind-by-carlos-ruiz-zafon/">
#          <div class="three-d">
#           <div class="cover">
#            <span class="">
#             <img alt="The Shadow of the Wind Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780143126393" src=""/>
#            </span>
#            <div class="cover__backcover-container">
#             <img alt="The Shadow of the Wind Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780143126393" src=""/>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="buy">
#        <div class="buy_clmn buy_small">
#         <h3>
#          Hardcover
#          <div class="buy-price">
#           $30.00
#          </div>
#         </h3>
#         <div class="cart-bttns">
#          <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
#           <button type="submit">
#            Add to cart
#           </button>
#           <input id="itemISBN" name="itemISBN" type="hidden" value="9780143126393"/>
#           <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
#           <input id="siteName" name="siteName" type="hidden" value="prh"/>
#           <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
#           <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
#           <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
#          </form>
#         </div>
#        </div>
#        <div class="buy_clmn">
#         <div class="ajax-wait hidden">
#         </div>
#         <h3>
#          Also available from:
#         </h3>
#         <a class="btn buy hidden" rel="popover">
#          Buy
#         </a>
#         <div class="hidden parking-lot 9780143126393 by_work amazonlast">
#         </div>
#        </div>
#       </div>
#      </div>
#     </li>
#     <li authid="31223" author="J.R.R. Tolkien" cat-data="Epic Fantasy" class="inner-facade no-bg-el" data-format="Paperback" data-format-name="Mass Market Paperback" data-isbn="9780345339706" format-data="Paperback" id="book5" imprint-data="Del Rey" isbn="9780345339706" ttl="The Fellowship of the Ring" workid="179203">
#      <div class="container relative">
#       <div class="list-number">
#        <span>
#         5
#        </span>
#       </div>
#       <div class="list-meta-wrap">
#        <div class="list-meta seemoreenable">
#         <div class="readdown-cover-wrap-desktop" href="/books/179203/the-fellowship-of-the-ring-by-jrr-tolkien/">
#          <div class="three-d">
#           <div class="cover">
#            <span class="">
#             <img alt="The Fellowship of the Ring Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780345339706" src=""/>
#            </span>
#            <div class="cover__backcover-container">
#             <img alt="The Fellowship of the Ring Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780345339706" src=""/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <h2>
#          <a href="/books/179203/the-fellowship-of-the-ring-by-jrr-tolkien/">
#           The Lord of the Rings
#          </a>
#         </h2>
#         <h2 class="author">
#          by J.R.R. Tolkien
#         </h2>
#         <div class="desc">
#          Most people have seen the epic movie, but have you read the book?
#         </div>
#         <div class="readdown-cover-wrap-mobile" href="/books/179203/the-fellowship-of-the-ring-by-jrr-tolkien/">
#          <div class="three-d">
#           <div class="cover">
#            <span class="">
#             <img alt="The Fellowship of the Ring Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780345339706" src=""/>
#            </span>
#            <div class="cover__backcover-container">
#             <img alt="The Fellowship of the Ring Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780345339706" src=""/>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="buy">
#        <div class="buy_clmn buy_small">
#         <h3>
#          Mass Market Paperback
#          <div class="buy-price">
#           $8.99
#          </div>
#         </h3>
#         <div class="cart-bttns">
#          <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
#           <button type="submit">
#            Add to cart
#           </button>
#           <input id="itemISBN" name="itemISBN" type="hidden" value="9780345339706"/>
#           <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
#           <input id="siteName" name="siteName" type="hidden" value="prh"/>
#           <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
#           <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
#           <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
#          </form>
#         </div>
#        </div>
#        <div class="buy_clmn">
#         <div class="ajax-wait hidden">
#         </div>
#         <h3>
#          Also available from:
#         </h3>
#         <a class="btn buy hidden" rel="popover">
#          Buy
#         </a>
#         <div class="hidden parking-lot 9780345339706 by_work amazonlast">
#         </div>
#        </div>
#       </div>
#      </div>
#     </li>
#     <li authid="26491" author="Salman Rushdie" cat-data="Literary Fiction | Science Fiction &amp; Fantasy | Paranormal Fiction" class="inner-facade no-bg-el" data-ebook="9780307786654" data-format="Paperback" data-format-name="Paperback" data-isbn="9780812976717" format-data="Paperback,Ebook" id="book6" imprint-data="Random House Trade Paperbacks" isbn="9780812976717" ttl="The Satanic Verses" workid="158937">
#      <div class="container relative">
#       <div class="list-number">
#        <span>
#         6
#        </span>
#       </div>
#       <div class="list-meta-wrap">
#        <div class="list-meta seemoreenable">
#         <div class="readdown-cover-wrap-desktop" href="/books/158937/the-satanic-verses-by-salman-rushdie/">
#          <div class="three-d">
#           <div class="cover">
#            <span class="">
#             <img alt="The Satanic Verses Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780812976717" src=""/>
#            </span>
#            <div class="cover__backcover-container">
#             <img alt="The Satanic Verses Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780812976717" src=""/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <h2>
#          <a href="/books/158937/the-satanic-verses-by-salman-rushdie/">
#           The Satanic Verses
#          </a>
#         </h2>
#         <h2 class="author">
#          by Salman Rushdie
#         </h2>
#         <div class="desc">
#          Known as one of Salman Rushdie’s greatest works, this book is definitely on the TBR list.
#         </div>
#         <div class="readdown-cover-wrap-mobile" href="/books/158937/the-satanic-verses-by-salman-rushdie/">
#          <div class="three-d">
#           <div class="cover">
#            <span class="">
#             <img alt="The Satanic Verses Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780812976717" src=""/>
#            </span>
#            <div class="cover__backcover-container">
#             <img alt="The Satanic Verses Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780812976717" src=""/>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="buy">
#        <div class="buy_clmn buy_small">
#         <h3>
#          Paperback
#          <div class="buy-price">
#           $17.00
#          </div>
#         </h3>
#         <div class="cart-bttns">
#          <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
#           <button type="submit">
#            Add to cart
#           </button>
#           <input id="itemISBN" name="itemISBN" type="hidden" value="9780812976717"/>
#           <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
#           <input id="siteName" name="siteName" type="hidden" value="prh"/>
#           <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
#           <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
#           <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
#          </form>
#         </div>
#        </div>
#        <div class="buy_clmn">
#         <div class="ajax-wait hidden">
#         </div>
#         <h3>
#          Also available from:
#         </h3>
#         <a class="btn buy hidden" rel="popover">
#          Buy
#         </a>
#         <div class="hidden parking-lot 9780812976717 by_work amazonlast">
#         </div>
#        </div>
#       </div>
#      </div>
#     </li>
#     <li authid="71920" author="Miguel de Cervantes" cat-data="Literary Fiction | Fiction Classics | Historical Fiction" class="inner-facade no-bg-el" data-format="Hardcover" data-format-name="Hardcover" data-isbn="9780679407584" format-data="Hardcover" id="book7" imprint-data="Everyman's Library" isbn="9780679407584" ttl="Don Quixote" workid="25678">
#      <div class="container relative">
#       <div class="list-number">
#        <span>
#         7
#        </span>
#       </div>
#       <div class="list-meta-wrap">
#        <div class="list-meta seemoreenable">
#         <div class="readdown-cover-wrap-desktop" href="/books/25678/don-quixote-by-miguel-de-cervantes/">
#          <div class="three-d">
#           <div class="cover">
#            <span class="">
#             <img alt="Don Quixote Book Cover Picture" class="img-responsive lazyload" data-src="https://images4.penguinrandomhouse.com/cover/9780679407584" src=""/>
#            </span>
#            <div class="cover__backcover-container">
#             <img alt="Don Quixote Book Cover Picture" class="img-responsive lazyload" data-src="https://images4.penguinrandomhouse.com/cover/9780679407584" src=""/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <h2>
#          <a href="/books/25678/don-quixote-by-miguel-de-cervantes/">
#           Don Quixote
#          </a>
#         </h2>
#         <h2 class="author">
#          by Miguel de Cervantes
#         </h2>
#         <div class="desc">
#          It’s no surprise that one of the best books of all time should be read.
#         </div>
#         <div class="readdown-cover-wrap-mobile" href="/books/25678/don-quixote-by-miguel-de-cervantes/">
#          <div class="three-d">
#           <div class="cover">
#            <span class="">
#             <img alt="Don Quixote Book Cover Picture" class="img-responsive lazyload" data-src="https://images4.penguinrandomhouse.com/cover/9780679407584" src=""/>
#            </span>
#            <div class="cover__backcover-container">
#             <img alt="Don Quixote Book Cover Picture" class="img-responsive lazyload" data-src="https://images4.penguinrandomhouse.com/cover/9780679407584" src=""/>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="buy">
#        <div class="buy_clmn buy_small">
#         <h3>
#          Hardcover
#          <div class="buy-price">
#           $30.00
#          </div>
#         </h3>
#         <div class="cart-bttns">
#          <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
#           <button type="submit">
#            Add to cart
#           </button>
#           <input id="itemISBN" name="itemISBN" type="hidden" value="9780679407584"/>
#           <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
#           <input id="siteName" name="siteName" type="hidden" value="prh"/>
#           <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
#           <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
#           <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
#          </form>
#         </div>
#        </div>
#        <div class="buy_clmn">
#         <div class="ajax-wait hidden">
#         </div>
#         <h3>
#          Also available from:
#         </h3>
#         <a class="btn buy hidden" rel="popover">
#          Buy
#         </a>
#         <div class="hidden parking-lot 9780679407584 by_work amazonlast">
#         </div>
#        </div>
#       </div>
#      </div>
#     </li>
#     <li authid="24658" author="Philip Pullman" cat-data="Children's Middle Grade Action &amp; Adventure Books | Children's Picture Books" class="inner-facade no-bg-el" data-ebook="9780440418603" data-format="Paperback" data-format-name="Paperback" data-isbn="9780593178553" format-data="Paperback,Hardcover,Ebook,Audio" id="book8" imprint-data="Knopf Books for Young Readers" isbn="9780593178553" ttl="His Dark Materials: The Golden Compass (HBO Tie-In Edition)" workid="136447">
#      <div class="container relative">
#       <div class="list-number">
#        <span>
#         8
#        </span>
#       </div>
#       <div class="list-meta-wrap">
#        <div class="list-meta seemoreenable">
#         <div class="readdown-cover-wrap-desktop" href="/books/136447/his-dark-materials-the-golden-compass-hbo-tie-in-edition-by-philip-pullman/">
#          <div class="three-d">
#           <div class="cover">
#            <span class="">
#             <img alt="His Dark Materials: The Golden Compass (HBO Tie-In Edition) Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780593178553" src=""/>
#            </span>
#            <div class="cover__backcover-container">
#             <img alt="His Dark Materials: The Golden Compass (HBO Tie-In Edition) Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780593178553" src=""/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <h2>
#          <a href="/books/136447/his-dark-materials-the-golden-compass-hbo-tie-in-edition-by-philip-pullman/">
#           The Golden Compass
#          </a>
#         </h2>
#         <h2 class="author">
#          by Philip Pullman
#         </h2>
#         <div class="desc">
#          Go on an adventure this year with this thrilling fantasy tale.
#         </div>
#         <div class="readdown-cover-wrap-mobile" href="/books/136447/his-dark-materials-the-golden-compass-hbo-tie-in-edition-by-philip-pullman/">
#          <div class="three-d">
#           <div class="cover">
#            <span class="">
#             <img alt="His Dark Materials: The Golden Compass (HBO Tie-In Edition) Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780593178553" src=""/>
#            </span>
#            <div class="cover__backcover-container">
#             <img alt="His Dark Materials: The Golden Compass (HBO Tie-In Edition) Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780593178553" src=""/>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="buy">
#        <div class="buy_clmn buy_small">
#         <h3>
#          Paperback
#          <div class="buy-price">
#           $12.99
#          </div>
#         </h3>
#         <div class="cart-bttns">
#          <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
#           <button type="submit">
#            Add to cart
#           </button>
#           <input id="itemISBN" name="itemISBN" type="hidden" value="9780593178553"/>
#           <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
#           <input id="siteName" name="siteName" type="hidden" value="prh"/>
#           <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
#           <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
#           <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
#          </form>
#         </div>
#        </div>
#        <div class="buy_clmn">
#         <div class="ajax-wait hidden">
#         </div>
#         <h3>
#          Also available from:
#         </h3>
#         <a class="btn buy hidden" rel="popover">
#          Buy
#         </a>
#         <div class="hidden parking-lot 9780593178553 by_work amazonlast">
#         </div>
#        </div>
#       </div>
#      </div>
#     </li>
#     <li authid="12549" author="Joseph Heller" cat-data="Literary Fiction | Fiction Classics | Military Fiction" class="inner-facade no-bg-el" data-format="Hardcover" data-format-name="Hardcover" data-isbn="9780679437222" format-data="Hardcover" id="book9" imprint-data="Everyman's Library" isbn="9780679437222" ttl="Catch-22" workid="78171">
#      <div class="container relative">
#       <div class="list-number">
#        <span>
#         9
#        </span>
#       </div>
#       <div class="list-meta-wrap">
#        <div class="list-meta seemoreenable">
#         <div class="readdown-cover-wrap-desktop" href="/books/78171/catch-22-by-joseph-heller/">
#          <div class="three-d">
#           <div class="cover">
#            <span class="">
#             <img alt="Catch-22 Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780679437222" src=""/>
#            </span>
#            <div class="cover__backcover-container">
#             <img alt="Catch-22 Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780679437222" src=""/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <h2>
#          <a href="/books/78171/catch-22-by-joseph-heller/">
#           Catch-22
#          </a>
#         </h2>
#         <h2 class="author">
#          by Joseph Heller
#         </h2>
#         <div class="desc">
#          If this wasn’t already required reading in your school, it’s about time you’ve read it.
#         </div>
#         <div class="readdown-cover-wrap-mobile" href="/books/78171/catch-22-by-joseph-heller/">
#          <div class="three-d">
#           <div class="cover">
#            <span class="">
#             <img alt="Catch-22 Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780679437222" src=""/>
#            </span>
#            <div class="cover__backcover-container">
#             <img alt="Catch-22 Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780679437222" src=""/>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="buy">
#        <div class="buy_clmn buy_small">
#         <h3>
#          Hardcover
#          <div class="buy-price">
#           $28.00
#          </div>
#         </h3>
#         <div class="cart-bttns">
#          <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
#           <button type="submit">
#            Add to cart
#           </button>
#           <input id="itemISBN" name="itemISBN" type="hidden" value="9780679437222"/>
#           <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
#           <input id="siteName" name="siteName" type="hidden" value="prh"/>
#           <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
#           <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
#           <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
#          </form>
#         </div>
#        </div>
#        <div class="buy_clmn">
#         <div class="ajax-wait hidden">
#         </div>
#         <h3>
#          Also available from:
#         </h3>
#         <a class="btn buy hidden" rel="popover">
#          Buy
#         </a>
#         <div class="hidden parking-lot 9780679437222 by_work amazonlast">
#         </div>
#        </div>
#       </div>
#      </div>
#     </li>
#     <li authid="22880" author="George Orwell" cat-data="Fiction" class="inner-facade no-bg-el" data-format="Paperback" data-format-name="Paperback" data-isbn="9780452284234" format-data="Paperback" id="book10" imprint-data="Berkley" isbn="9780452284234" ttl="1984" workid="326569">
#      <div class="container relative">
#       <div class="list-number">
#        <span>
#         10
#        </span>
#       </div>
#       <div class="list-meta-wrap">
#        <div class="list-meta seemoreenable">
#         <div class="readdown-cover-wrap-desktop" href="/books/326569/1984-by-george-orwell-with-a-foreword-by-thomas-pynchon/">
#          <div class="three-d">
#           <div class="cover">
#            <span class="">
#             <img alt="1984 Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780452284234" src=""/>
#            </span>
#            <div class="cover__backcover-container">
#             <img alt="1984 Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780452284234" src=""/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <h2>
#          <a href="/books/326569/1984-by-george-orwell-with-a-foreword-by-thomas-pynchon/">
#           1984
#          </a>
#         </h2>
#         <h2 class="author">
#          by George Orwell
#         </h2>
#         <div class="desc">
#          We were pretty certain you’ve read one of the best books of all time, but in case you haven’t, now’s your chance.
#         </div>
#         <div class="readdown-cover-wrap-mobile" href="/books/326569/1984-by-george-orwell-with-a-foreword-by-thomas-pynchon/">
#          <div class="three-d">
#           <div class="cover">
#            <span class="">
#             <img alt="1984 Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780452284234" src=""/>
#            </span>
#            <div class="cover__backcover-container">
#             <img alt="1984 Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780452284234" src=""/>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="buy">
#        <div class="buy_clmn buy_small">
#         <h3>
#          Paperback
#          <div class="buy-price">
#           $17.00
#          </div>
#         </h3>
# ...
#            </div>
#           </div>
#          </div>
#         </div>
#         <h2>
#          <a href="/books/557793/the-handmaids-tale-movie-tie-in-by-margaret-atwood/9780385490818/">
#           The Handmaid’s Tale
#          </a>
#         </h2>
#         <h2 class="author">
#          by Margaret Atwood
#         </h2>
#         <div class="desc">
#          Same goes for Margaret Atwood, and
#          <em>
#           The Handmaid’s Tale
#          </em>
#          is definitely a classic.
#         </div>
#         <div class="readdown-cover-wrap-mobile" href="/books/557793/the-handmaids-tale-movie-tie-in-by-margaret-atwood/9780385490818/">
#          <div class="three-d">
#           <div class="cover">
#            <span class="deferred-view-scroll">
#             <img alt="The Handmaid's Tale (Movie Tie-in) Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9780385490818" src=""/>
#            </span>
#            <div class="cover__backcover-container deferred-view-scroll">
#             <img alt="The Handmaid's Tale (Movie Tie-in) Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9780385490818" src=""/>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="buy">
#        <div class="buy_clmn buy_small">
#         <h3>
#          Paperback
#          <div class="buy-price">
#           $15.95
#          </div>
#         </h3>
#         <div class="cart-bttns">
#          <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
#           <button type="submit">
#            Add to cart
#           </button>
#           <input id="itemISBN" name="itemISBN" type="hidden" value="9780385490818"/>
#           <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
#           <input id="siteName" name="siteName" type="hidden" value="prh"/>
#           <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
#           <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
#           <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
#          </form>
#         </div>
#        </div>
#        <div class="buy_clmn">
#         <div class="ajax-wait hidden">
#         </div>
#         <h3>
#          Also available from:
#         </h3>
#         <a class="btn buy hidden" rel="popover">
#          Buy
#         </a>
#         <div class="hidden parking-lot 9780385490818 by_isbn amazonlast">
#         </div>
#        </div>
#       </div>
#      </div>
#     </li>
#    </ol>
#    <div id="read-down-list-flyin-anchor">
#    </div>
#    <div class="inner-facade tertiary share">
#     <div class="container">
#      <!-- Start Scaffolding -->
#      <div class="scaffolding row">
#       <div class="col-xs-1 col-sm-0 col-md-0 col-lg-0">
#       </div>
#       <div class="main-content col-xs-14 col-sm-16 col-md-16 col-lg-16">
#        <div id="share-links-wrap-mobile">
#         <div class="share-links" id="share-collapse">
#          <ul class="share-items" data-description="Reading lists begin as a shelf full of hope until the year flies by, and you find yourself flooded with procrastination. Cheers to the books we've been meaning to read all these years and should probably start at some point." data-display="detail" data-listtitle="21 Books You've Been Meaning To Read" data-sharedimage="https://assets.penguinrandomhouse.com/the-read-down-images/list-4453-fb-triad.png" data-sharedlink="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read" data-sharemessageservice="https://services.penguin.com/rest/v1/json/socialmedia/sharemessage/get" data-sharetypeid="11" data-siteid="301">
#           <li class="header">
#            Share:
#           </li>
#           <li data-fbappid="350479041816117" data-socialmediaid="1">
#            <a class="facebook">
#             <div class="fa fa-facebook">
#              <span>
#               Share on Facebook
#              </span>
#             </div>
#            </a>
#           </li>
#           <li data-socialmediaid="2">
#            <a class="twitter">
#             <div class="fa fa-twitter">
#              <span>
#               Tweet
#              </span>
#             </div>
#            </a>
#           </li>
#           <li data-socialmediaid="6">
#            <a class="pinterest">
#             <div class="fa fa-pinterest">
#              <span>
#               Pin it
#              </span>
#             </div>
#            </a>
#           </li>
#           <li data-socialmediaid="3">
#            <a class="tumblr">
#             <div class="fa fa-tumblr">
#              <span>
#               Share on Tumblr
#              </span>
#             </div>
#            </a>
#           </li>
#           <li data-socialmediaid="9">
#            <a class="sms-share">
#             <span>
#              SMS
#             </span>
#            </a>
#           </li>
#           <li data-socialmediaid="8">
#            <a class="envelope">
#             <div class="fa fa-envelope">
#              <span>
#               Email
#              </span>
#             </div>
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#       <!-- main-content -->
#       <div class="col-xs-1 col-sm-0 col-md-0 col-lg-0">
#       </div>
#      </div>
#      <!-- scaffolding row -->
#     </div>
#     <!-- container -->
#    </div>
#    <div class="inner-facade tertiary filed-under">
#     <div class="container">
#      <!-- Start Scaffolding -->
#      <div class="scaffolding row">
#       <div class="col-xs-1 col-sm-0 col-md-0 col-lg-0">
#       </div>
#       <div class="main-content col-xs-14 col-sm-16 col-md-16 col-lg-16">
#        <div class="inner">
#         <h4>
#          Find other titles in
#         </h4>
#         <div class="list-categories-read-down count-1">
#          <a class="list-cat all" href="/books/fiction">
#           Fiction
#          </a>
#          <span class="pipe">
#          </span>
#         </div>
#        </div>
#        <!-- main-content -->
#        <div class="col-xs-1 col-sm-0 col-md-0 col-lg-0">
#        </div>
#       </div>
#      </div>
#      <!-- scaffolding row -->
#     </div>
#     <!-- container -->
#    </div>
#    <div class="inner-facade tertiary relatedlists">
#     <div class="container">
#      <!-- Start Scaffolding -->
#      <div class="scaffolding row">
#       <div class="main-content col-xs-14 col-sm-16 col-md-16 col-lg-16">
#        <h4>
#         Related Lists:
#        </h4>
#        <div id="async-carousel">
#        </div>
#       </div>
#       <!-- main-content -->
#       <div class="col-xs-1 col-sm-0 col-md-0 col-lg-0">
#       </div>
#      </div>
#      <!-- scaffolding row -->
#     </div>
#     <!-- container -->
#    </div>
#    <!-- Start sticky arrow -->
#    <a href="#top" id="stickyarrow">
#     <span>
#      Back to Top
#     </span>
#    </a>
#    <!-- / End sticky arrow -->
#    <div class="inner-facade-footer">
#     <!-- Start Footer -->
#     <footer class="footer-wrap">
#      <div class="container">
#       <div class="row">
#        <div class="main-footer clearfix">
#         <ul class="footer-links">
#          <span class="dsktop-right">
#           <li>
#            Connect
#           </li>
#           <p class="sgn-mssg">
#            Sign up for news about books, authors, and more from Penguin Random House
#           </p>
#           <button class="btn share" rel="popover" title="" type="button">
#            <i class="fa fa-envelope">
#            </i>
#            Stay in touch
#           </button>
#           <ul class="socialft">
#            <li>
#             <a class="fttr social facebook" href="https://www.facebook.com/PenguinRandomHouse" rel="noopener noreferrer" target="_blank">
#              <i class="fa fa-facebook">
#              </i>
#             </a>
#            </li>
#            <li>
#             <a class="fttr social twitter" href="https://twitter.com/penguinrandom" rel="noopener noreferrer" target="_blank">
#              <i class="fa fa-twitter">
#              </i>
#             </a>
#            </li>
#            <li>
#             <a class="fttr social youtube-play" href="https://www.youtube.com/channel/UC4OnzY1OgwUE0XPAHpqlcvQ" rel="noopener noreferrer" target="_blank">
#              <i class="fa fa-youtube-play">
#              </i>
#             </a>
#            </li>
#            <li>
#             <a class="fttr social linkedin" href="https://www.linkedin.com/company/penguin-random-house-publishing" rel="noopener noreferrer" target="_blank">
#              <i class="fa fa-linkedin">
#              </i>
#             </a>
#            </li>
#            <li>
#             <a class="fttr social pinterest" href="http://pinterest.com/penguinrandom/" rel="noopener noreferrer" target="_blank">
#              <i class="fa fa-pinterest-p">
#              </i>
#             </a>
#            </li>
#            <li>
#             <a class="fttr social instagram" href="http://instagram.com/penguinrandomhouse" rel="noopener noreferrer" target="_blank">
#              <i class="fa fa-instagram">
#              </i>
#             </a>
#            </li>
#           </ul>
#          </span>
#          <span>
#           <li>
#            About
#           </li>
#           <li>
#            <a href="/about-us/news/" rel="nofollow" title="">
#             News
#            </a>
#           </li>
#           <li>
#            <a href="https://careers.penguinrandomhouse.com/" rel="nofollow" target="_blank" title="">
#             Careers
#            </a>
#           </li>
#           <li>
#            <a href="/about-us/contact-us/" rel="nofollow" title="">
#             Contact Us
#            </a>
#           </li>
#           <li>
#            <a href="/faqs/" rel="nofollow" title="">
#             FAQ
#            </a>
#           </li>
#           <li>
#            <a href="/preferences/" rel="nofollow" title="">
#             Email Preferences
#            </a>
#           </li>
#           <li>
#            <a href="/terms/" rel="nofollow" title="">
#             Terms of Use
#            </a>
#           </li>
#           <li>
#            <a href="/privacy/" rel="nofollow" title="">
#             Privacy Policy
#            </a>
#           </li>
#           <li>
#            <a href="/privacy/right-to-opt-out-of-sale-form/" rel="nofollow" title="">
#             Do Not Sell My Personal Info
#            </a>
#           </li>
#          </span>
#          <span>
#           <li>
#            Resources
#           </li>
#           <li>
#            <a href="/faqs/#shopping" rel="nofollow" title="">
#             Shopping &amp; Shipping FAQ
#            </a>
#           </li>
#           <li>
#            <a href="https://penguinrandomhouseeducation.com/" rel="nofollow" target="_blank" title="">
#             For Educators
#            </a>
#           </li>
#           <li>
#            <a href="http://www.penguinrandomhouse.biz/" rel="nofollow" title="">
#             penguinrandomhouse.biz
#            </a>
#           </li>
#           <li>
#            <a href="/media-queries/" rel="nofollow" title="">
#             Media Queries
#            </a>
#           </li>
#           <li>
#            <a href="http://www.penguinrandomhouse.biz/rights/" rel="nofollow" target="_blank" title="">
#             Subrights
#            </a>
#           </li>
#           <li>
#            <a href="https://permissions.penguinrandomhouse.com/" rel="nofollow" target="_blank" title="">
#             Permissions
#            </a>
#           </li>
#           <li>
#            <a href="http://www.prhspeakers.com/" rel="nofollow" target="_blank" title="">
#             Speakers Bureau
#            </a>
#           </li>
#           <li>
#            <a href="https://companyreads.prhspeakers.com/" rel="nofollow" title="">
#             Company Reads
#            </a>
#           </li>
#          </span>
#          <span class="dsktop-left">
#           <li>
#            <a href="/">
#             <div class="footer-logo">
#             </div>
#            </a>
#           </li>
#           <li>
#            <a href="https://global.penguinrandomhouse.com" rel="noopener noreferrer" target="_blank">
#             global.penguinrandomhouse.com
#            </a>
#           </li>
#           <li class="ft-cr">
#            © 2020 Penguin Random House
#           </li>
#          </span>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </footer>
#     <!-- / End  Footer -->
#     <footer class="mobile">
#      <div class="bottom-tabs">
#       <div class="tab-holder">
#        <div class="tab">
#         <a href="/books">
#          Books
#         </a>
#        </div>
#        <div class="tab">
#         <a href="/series">
#          Series
#         </a>
#        </div>
#        <!--<div class="tab tab-wide"><a href="/authors">Authors</a></div>-->
#        <div class="tab tab-wide">
#         <a href="/about-us">
#          <nobr>
#           About Us
#          </nobr>
#         </a>
#        </div>
#        <div class="tab tab-wide" id="myprh-tab-m">
#        </div>
#       </div>
#      </div>
#     </footer>
#    </div>
#    <!-- inner-facade END -->
#    <div class="container">
#     <p class="footer-bttm-links-visit">
#      Visit other sites in the Penguin Random House Network
#     </p>
#     <div class="footer-bttm-links">
#      <div>
#       <a class="footer-bttm-link" href="http://www.readbrightly.com/?ref=822975591A1E" rel="nofollow" target="_blank" title="">
#        <img alt="" src="https://assets.penguinrandomhouse.com/wp-content/uploads/2015/04/01075801/thumbnail.png"/>
#       </a>
#       <h4>
#        Brightly
#       </h4>
#       Raise kids who love to read
#      </div>
#      <div>
#       <a class="footer-bttm-link" href="http://www.tastecooking.com/?ref=E8C77968C21F" rel="nofollow" target="_blank" title="TASTE img">
#        <img alt="TASTE img" src="https://assets.penguinrandomhouse.com/wp-content/uploads/2017/03/03173807/tastelogo1.png"/>
#       </a>
#       <h4>
#        TASTE
#       </h4>
#       An online magazine for today’s home cook
#      </div>
#      <div>
#       <a class="footer-bttm-link" href="http://www.litflash.com/" rel="nofollow" target="" title="">
#        <img alt="" src="https://assets.penguinrandomhouse.com/wp-content/uploads/2016/08/01074758/litflashlogo68x68.jpg"/>
#       </a>
#       <h4>
#        LitFlash
#       </h4>
#       The eBooks you want at the lowest prices
#      </div>
#      <div>
#       <a class="footer-bttm-link" href="http://readitforward.com" rel="nofollow" target="" title="">
#        <img alt="" src="https://assets.penguinrandomhouse.com/wp-content/uploads/2016/05/01074912/riflogonew.jpg"/>
#       </a>
#       <h4>
#        Read it Forward
#       </h4>
#       Read it first. Pass it on!
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="ftr-signup" style="display:none;">
#    <span class="close">
#    </span>
#    <p class="hdr">
#     Stay in Touch
#    </p>
#    <form action="/ajax/newsletters-sub" class="ftr-newsletter-subform" id="ftr-newsletter-subform" name="newsletter-subform">
#     <input name="acquisition_code" type="hidden" value="PRH_FOOTER_STATIC_ONGOING"/>
#     <input class="newsletter-pref" id="news-pref1" name="general" type="hidden" value="true"/>
#     <div class="email-wrap-div">
#      <input autocomplete="off" class="email-box" id="newsletter-email-box" name="_email" placeholder="Enter Email" title="Email address" type="email" value=""/>
#      <button class="btn subscribe">
#       Sign up
#      </button>
#     </div>
#     <div class="fielderr _email hidden">
#      Please enter a valid email address
#     </div>
#     <div class="fielderr processing hidden">
#      We are experiencing technical difficulties.  Please try again later.
#     </div>
#     <p class="terms">
#      By clicking Sign Up, I acknowledge that I have read and agree to Penguin Random House's
#      <a href="/privacy">
#       Privacy Policy
#      </a>
#      and
#      <a href="/terms">
#       Terms of Use
#      </a>
#      .
#     </p>
#    </form>
#   </div>
#   <!-- / End Main Page Wrap -->
#  </body>
# </html>

# %%
soup = bs(requests.get(link).text, 'html.parser')

# %%
books = soup.find('ol', {'class': 'awesome-list'})

# %%
books
# Out:
# <ol class="awesome-list">
# <li authid="31231" author="Leo Tolstoy" cat-data="Literary Fiction | Fiction Classics | Historical Fiction" class="inner-facade" data-ebook="9780307806581" data-format="Paperback" data-format-name="Paperback" data-isbn="9781400079988" format-data="Paperback,Ebook" id="book1" imprint-data="Vintage" isbn="9781400079988" ttl="War and Peace" workid="208646">
# <div class="container relative">
# <div class="list-number"><span>1</span></div>
# <div class="list-meta-wrap">
# <div class="list-meta seemoreenable">
# <div class="readdown-cover-wrap-desktop" href="/books/208646/war-and-peace-by-leo-tolstoy-a-new-translation-by-richard-pevear-and-larissa-volokhonsky/">
# <div class="three-d">
# <div class="cover">
# <span class="">
# <img alt="War and Peace Book Cover Picture" class="img-responsive" src="https://images4.penguinrandomhouse.com/cover/9781400079988"/></span>
# <div class="cover__backcover-container">
# <img alt="War and Peace Book Cover Picture" class="cover__backcover" src="https://images4.penguinrandomhouse.com/cover/9781400079988"/> </div>
# </div>
# </div>
# </div>
# <h2><a href="/books/208646/war-and-peace-by-leo-tolstoy-a-new-translation-by-richard-pevear-and-larissa-volokhonsky/">War and Peace</a></h2>
# <h2 class="author">by Leo Tolstoy</h2>
# <div class="desc">A legendary masterpiece, this book is synonymous with difficult reading, so why not challenge yourshelf.</div>
# <div class="readdown-cover-wrap-mobile" href="/books/208646/war-and-peace-by-leo-tolstoy-a-new-translation-by-richard-pevear-and-larissa-volokhonsky/">
# <div class="three-d">
# <div class="cover">
# <span class="">
# <img alt="War and Peace Book Cover Picture" class="img-responsive" src="https://images4.penguinrandomhouse.com/cover/9781400079988"/></span>
# <div class="cover__backcover-container">
# <img alt="War and Peace Book Cover Picture" class="cover__backcover" src="https://images4.penguinrandomhouse.com/cover/9781400079988"/> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="buy">
# <div class="buy_clmn buy_small">
# <h3>Paperback<div class="buy-price">$20.00</div></h3>
# <div class="cart-bttns">
# <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
# <button type="submit">Add to cart</button>
# <input id="itemISBN" name="itemISBN" type="hidden" value="9781400079988"/>
# <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
# <input id="siteName" name="siteName" type="hidden" value="prh"/>
# <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
# </form>
# </div>
# </div>
# <div class="buy_clmn">
# <div class="ajax-wait hidden"></div>
# <h3>Also available from:</h3>
# <a class="btn buy hidden" rel="popover">Buy</a>
# <div class="hidden parking-lot 9781400079988 by_work amazonlast"></div>
# </div>
# </div>
# </div>
# </li>
# <li authid="21332" author="Toni Morrison" cat-data="Literary Fiction" class="inner-facade no-bg-el" data-ebook="9780307388124" data-format="Paperback" data-format-name="Paperback" data-isbn="9781400033423" format-data="Paperback,Hardcover,Ebook,Audio" id="book2" imprint-data="Vintage" isbn="9781400033423" ttl="Song of Solomon" workid="117657">
# <div class="container relative">
# <div class="list-number"><span>2</span></div>
# <div class="list-meta-wrap">
# <div class="list-meta seemoreenable">
# <div class="readdown-cover-wrap-desktop" href="/books/117657/song-of-solomon-by-toni-morrison/">
# <div class="three-d">
# <div class="cover">
# <span class="">
# <img alt="Song of Solomon Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9781400033423" src=""/></span>
# <div class="cover__backcover-container">
# <img alt="Song of Solomon Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9781400033423" src=""/> </div>
# </div>
# </div>
# </div>
# <h2><a href="/books/117657/song-of-solomon-by-toni-morrison/">Song of Solomon</a></h2>
# <h2 class="author">by Toni Morrison</h2>
# <div class="desc">One must always read a novel by this Nobel Prize winning author.</div>
# <div class="readdown-cover-wrap-mobile" href="/books/117657/song-of-solomon-by-toni-morrison/">
# <div class="three-d">
# <div class="cover">
# <span class="">
# <img alt="Song of Solomon Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9781400033423" src=""/></span>
# <div class="cover__backcover-container">
# <img alt="Song of Solomon Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9781400033423" src=""/> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="buy">
# <div class="buy_clmn buy_small">
# <h3>Paperback<div class="buy-price">$16.00</div></h3>
# <div class="cart-bttns">
# <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
# <button type="submit">Add to cart</button>
# <input id="itemISBN" name="itemISBN" type="hidden" value="9781400033423"/>
# <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
# <input id="siteName" name="siteName" type="hidden" value="prh"/>
# <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
# </form>
# </div>
# </div>
# <div class="buy_clmn">
# <div class="ajax-wait hidden"></div>
# <h3>Also available from:</h3>
# <a class="btn buy hidden" rel="popover">Buy</a>
# <div class="hidden parking-lot 9781400033423 by_work amazonlast"></div>
# </div>
# </div>
# </div>
# </li>
# <li authid="14876" author="James Joyce" cat-data="Fiction Classics | Literary Fiction" class="inner-facade no-bg-el" data-format="Paperback" data-format-name="Paperback" data-isbn="9780679722762" format-data="Paperback,Hardcover,Ebook" id="book3" imprint-data="Everyman's Library" isbn="9780679722762" ttl="Ulysses" workid="88933">
# <div class="container relative">
# <div class="list-number"><span>3</span></div>
# <div class="list-meta-wrap">
# <div class="list-meta seemoreenable">
# <div class="readdown-cover-wrap-desktop" href="/books/88933/ulysses-by-james-joyce/9780679722762/">
# <div class="three-d">
# <div class="cover">
# <span class="">
# <img alt="Ulysses Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780679722762" src=""/></span>
# <div class="cover__backcover-container">
# <img alt="Ulysses Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780679722762" src=""/> </div>
# </div>
# </div>
# </div>
# <h2><a href="/books/88933/ulysses-by-james-joyce/9780679722762/">Ulysses</a></h2>
# <h2 class="author">by James Joyce</h2>
# <div class="desc">“Joyce’s parallel use of <em>The Odyssey</em>…has the importance of a scientific discovery…” –T. S. Eliot</div>
# <div class="readdown-cover-wrap-mobile" href="/books/88933/ulysses-by-james-joyce/9780679722762/">
# <div class="three-d">
# <div class="cover">
# <span class="">
# <img alt="Ulysses Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780679722762" src=""/></span>
# <div class="cover__backcover-container">
# <img alt="Ulysses Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780679722762" src=""/> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="buy">
# <div class="buy_clmn buy_small">
# <h3>Paperback<div class="buy-price">$17.00</div></h3>
# <div class="cart-bttns">
# <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
# <button type="submit">Add to cart</button>
# <input id="itemISBN" name="itemISBN" type="hidden" value="9780679722762"/>
# <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
# <input id="siteName" name="siteName" type="hidden" value="prh"/>
# <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
# </form>
# </div>
# </div>
# <div class="buy_clmn">
# <div class="ajax-wait hidden"></div>
# <h3>Also available from:</h3>
# <a class="btn buy hidden" rel="popover">Buy</a>
# <div class="hidden parking-lot 9780679722762 by_isbn amazonlast"></div>
# </div>
# </div>
# </div>
# </li>
# <li authid="52439,227771" author="Carlos Ruiz Zafon,Jessica Hische" cat-data="Literary Fiction | Suspense &amp; Thriller" class="inner-facade no-bg-el" data-ebook="9781101147061" data-format="Hardcover" data-format-name="Hardcover" data-isbn="9780143126393" format-data="Paperback,Hardcover,Ebook,Audio" id="book4" imprint-data="Penguin Books" isbn="9780143126393" ttl="The Shadow of the Wind" workid="292766">
# <div class="container relative">
# <div class="list-number"><span>4</span></div>
# <div class="list-meta-wrap">
# <div class="list-meta seemoreenable">
# <div class="readdown-cover-wrap-desktop" href="/books/292766/the-shadow-of-the-wind-by-carlos-ruiz-zafon/">
# <div class="three-d">
# <div class="cover">
# <span class="">
# <img alt="The Shadow of the Wind Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780143126393" src=""/></span>
# <div class="cover__backcover-container">
# <img alt="The Shadow of the Wind Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780143126393" src=""/> </div>
# </div>
# </div>
# </div>
# <h2><a href="/books/292766/the-shadow-of-the-wind-by-carlos-ruiz-zafon/">The Shadow of the Wind</a></h2>
# <h2 class="author">by Carlos Ruiz Zafon</h2>
# <div class="desc">An incredible book by a beloved writer is a must read.</div>
# <div class="readdown-cover-wrap-mobile" href="/books/292766/the-shadow-of-the-wind-by-carlos-ruiz-zafon/">
# <div class="three-d">
# <div class="cover">
# <span class="">
# <img alt="The Shadow of the Wind Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780143126393" src=""/></span>
# <div class="cover__backcover-container">
# <img alt="The Shadow of the Wind Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780143126393" src=""/> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="buy">
# <div class="buy_clmn buy_small">
# <h3>Hardcover<div class="buy-price">$30.00</div></h3>
# <div class="cart-bttns">
# <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
# <button type="submit">Add to cart</button>
# <input id="itemISBN" name="itemISBN" type="hidden" value="9780143126393"/>
# <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
# <input id="siteName" name="siteName" type="hidden" value="prh"/>
# <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
# </form>
# </div>
# </div>
# <div class="buy_clmn">
# <div class="ajax-wait hidden"></div>
# <h3>Also available from:</h3>
# <a class="btn buy hidden" rel="popover">Buy</a>
# <div class="hidden parking-lot 9780143126393 by_work amazonlast"></div>
# </div>
# </div>
# </div>
# </li>
# <li authid="31223" author="J.R.R. Tolkien" cat-data="Epic Fantasy" class="inner-facade no-bg-el" data-format="Paperback" data-format-name="Mass Market Paperback" data-isbn="9780345339706" format-data="Paperback" id="book5" imprint-data="Del Rey" isbn="9780345339706" ttl="The Fellowship of the Ring" workid="179203">
# <div class="container relative">
# <div class="list-number"><span>5</span></div>
# <div class="list-meta-wrap">
# <div class="list-meta seemoreenable">
# <div class="readdown-cover-wrap-desktop" href="/books/179203/the-fellowship-of-the-ring-by-jrr-tolkien/">
# <div class="three-d">
# <div class="cover">
# <span class="">
# <img alt="The Fellowship of the Ring Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780345339706" src=""/></span>
# <div class="cover__backcover-container">
# <img alt="The Fellowship of the Ring Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780345339706" src=""/> </div>
# </div>
# </div>
# </div>
# <h2><a href="/books/179203/the-fellowship-of-the-ring-by-jrr-tolkien/">The Lord of the Rings</a></h2>
# <h2 class="author">by J.R.R. Tolkien</h2>
# <div class="desc">Most people have seen the epic movie, but have you read the book?</div>
# <div class="readdown-cover-wrap-mobile" href="/books/179203/the-fellowship-of-the-ring-by-jrr-tolkien/">
# <div class="three-d">
# <div class="cover">
# <span class="">
# <img alt="The Fellowship of the Ring Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780345339706" src=""/></span>
# <div class="cover__backcover-container">
# <img alt="The Fellowship of the Ring Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780345339706" src=""/> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="buy">
# <div class="buy_clmn buy_small">
# <h3>Mass Market Paperback<div class="buy-price">$8.99</div></h3>
# <div class="cart-bttns">
# <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
# <button type="submit">Add to cart</button>
# <input id="itemISBN" name="itemISBN" type="hidden" value="9780345339706"/>
# <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
# <input id="siteName" name="siteName" type="hidden" value="prh"/>
# <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
# </form>
# </div>
# </div>
# <div class="buy_clmn">
# <div class="ajax-wait hidden"></div>
# <h3>Also available from:</h3>
# <a class="btn buy hidden" rel="popover">Buy</a>
# <div class="hidden parking-lot 9780345339706 by_work amazonlast"></div>
# </div>
# </div>
# </div>
# </li>
# <li authid="26491" author="Salman Rushdie" cat-data="Literary Fiction | Science Fiction &amp; Fantasy | Paranormal Fiction" class="inner-facade no-bg-el" data-ebook="9780307786654" data-format="Paperback" data-format-name="Paperback" data-isbn="9780812976717" format-data="Paperback,Ebook" id="book6" imprint-data="Random House Trade Paperbacks" isbn="9780812976717" ttl="The Satanic Verses" workid="158937">
# <div class="container relative">
# <div class="list-number"><span>6</span></div>
# <div class="list-meta-wrap">
# <div class="list-meta seemoreenable">
# <div class="readdown-cover-wrap-desktop" href="/books/158937/the-satanic-verses-by-salman-rushdie/">
# <div class="three-d">
# <div class="cover">
# <span class="">
# <img alt="The Satanic Verses Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780812976717" src=""/></span>
# <div class="cover__backcover-container">
# <img alt="The Satanic Verses Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780812976717" src=""/> </div>
# </div>
# </div>
# </div>
# <h2><a href="/books/158937/the-satanic-verses-by-salman-rushdie/">The Satanic Verses</a></h2>
# <h2 class="author">by Salman Rushdie</h2>
# <div class="desc">Known as one of Salman Rushdie’s greatest works, this book is definitely on the TBR list.</div>
# <div class="readdown-cover-wrap-mobile" href="/books/158937/the-satanic-verses-by-salman-rushdie/">
# <div class="three-d">
# <div class="cover">
# <span class="">
# <img alt="The Satanic Verses Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780812976717" src=""/></span>
# <div class="cover__backcover-container">
# <img alt="The Satanic Verses Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780812976717" src=""/> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="buy">
# <div class="buy_clmn buy_small">
# <h3>Paperback<div class="buy-price">$17.00</div></h3>
# <div class="cart-bttns">
# <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
# <button type="submit">Add to cart</button>
# <input id="itemISBN" name="itemISBN" type="hidden" value="9780812976717"/>
# <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
# <input id="siteName" name="siteName" type="hidden" value="prh"/>
# <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
# </form>
# </div>
# </div>
# <div class="buy_clmn">
# <div class="ajax-wait hidden"></div>
# <h3>Also available from:</h3>
# <a class="btn buy hidden" rel="popover">Buy</a>
# <div class="hidden parking-lot 9780812976717 by_work amazonlast"></div>
# </div>
# </div>
# </div>
# </li>
# <li authid="71920" author="Miguel de Cervantes" cat-data="Literary Fiction | Fiction Classics | Historical Fiction" class="inner-facade no-bg-el" data-format="Hardcover" data-format-name="Hardcover" data-isbn="9780679407584" format-data="Hardcover" id="book7" imprint-data="Everyman's Library" isbn="9780679407584" ttl="Don Quixote" workid="25678">
# <div class="container relative">
# <div class="list-number"><span>7</span></div>
# <div class="list-meta-wrap">
# <div class="list-meta seemoreenable">
# <div class="readdown-cover-wrap-desktop" href="/books/25678/don-quixote-by-miguel-de-cervantes/">
# <div class="three-d">
# <div class="cover">
# <span class="">
# <img alt="Don Quixote Book Cover Picture" class="img-responsive lazyload" data-src="https://images4.penguinrandomhouse.com/cover/9780679407584" src=""/></span>
# <div class="cover__backcover-container">
# <img alt="Don Quixote Book Cover Picture" class="img-responsive lazyload" data-src="https://images4.penguinrandomhouse.com/cover/9780679407584" src=""/> </div>
# </div>
# </div>
# </div>
# <h2><a href="/books/25678/don-quixote-by-miguel-de-cervantes/">Don Quixote</a></h2>
# <h2 class="author">by Miguel de Cervantes</h2>
# <div class="desc">It’s no surprise that one of the best books of all time should be read.</div>
# <div class="readdown-cover-wrap-mobile" href="/books/25678/don-quixote-by-miguel-de-cervantes/">
# <div class="three-d">
# <div class="cover">
# <span class="">
# <img alt="Don Quixote Book Cover Picture" class="img-responsive lazyload" data-src="https://images4.penguinrandomhouse.com/cover/9780679407584" src=""/></span>
# <div class="cover__backcover-container">
# <img alt="Don Quixote Book Cover Picture" class="img-responsive lazyload" data-src="https://images4.penguinrandomhouse.com/cover/9780679407584" src=""/> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="buy">
# <div class="buy_clmn buy_small">
# <h3>Hardcover<div class="buy-price">$30.00</div></h3>
# <div class="cart-bttns">
# <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
# <button type="submit">Add to cart</button>
# <input id="itemISBN" name="itemISBN" type="hidden" value="9780679407584"/>
# <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
# <input id="siteName" name="siteName" type="hidden" value="prh"/>
# <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
# </form>
# </div>
# </div>
# <div class="buy_clmn">
# <div class="ajax-wait hidden"></div>
# <h3>Also available from:</h3>
# <a class="btn buy hidden" rel="popover">Buy</a>
# <div class="hidden parking-lot 9780679407584 by_work amazonlast"></div>
# </div>
# </div>
# </div>
# </li>
# <li authid="24658" author="Philip Pullman" cat-data="Children's Middle Grade Action &amp; Adventure Books | Children's Picture Books" class="inner-facade no-bg-el" data-ebook="9780440418603" data-format="Paperback" data-format-name="Paperback" data-isbn="9780593178553" format-data="Paperback,Hardcover,Ebook,Audio" id="book8" imprint-data="Knopf Books for Young Readers" isbn="9780593178553" ttl="His Dark Materials: The Golden Compass (HBO Tie-In Edition)" workid="136447">
# <div class="container relative">
# <div class="list-number"><span>8</span></div>
# <div class="list-meta-wrap">
# <div class="list-meta seemoreenable">
# <div class="readdown-cover-wrap-desktop" href="/books/136447/his-dark-materials-the-golden-compass-hbo-tie-in-edition-by-philip-pullman/">
# <div class="three-d">
# <div class="cover">
# <span class="">
# <img alt="His Dark Materials: The Golden Compass (HBO Tie-In Edition) Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780593178553" src=""/></span>
# <div class="cover__backcover-container">
# <img alt="His Dark Materials: The Golden Compass (HBO Tie-In Edition) Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780593178553" src=""/> </div>
# </div>
# </div>
# </div>
# <h2><a href="/books/136447/his-dark-materials-the-golden-compass-hbo-tie-in-edition-by-philip-pullman/">The Golden Compass</a></h2>
# <h2 class="author">by Philip Pullman</h2>
# <div class="desc">Go on an adventure this year with this thrilling fantasy tale.</div>
# <div class="readdown-cover-wrap-mobile" href="/books/136447/his-dark-materials-the-golden-compass-hbo-tie-in-edition-by-philip-pullman/">
# <div class="three-d">
# <div class="cover">
# <span class="">
# <img alt="His Dark Materials: The Golden Compass (HBO Tie-In Edition) Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780593178553" src=""/></span>
# <div class="cover__backcover-container">
# <img alt="His Dark Materials: The Golden Compass (HBO Tie-In Edition) Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780593178553" src=""/> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="buy">
# <div class="buy_clmn buy_small">
# <h3>Paperback<div class="buy-price">$12.99</div></h3>
# <div class="cart-bttns">
# <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
# <button type="submit">Add to cart</button>
# <input id="itemISBN" name="itemISBN" type="hidden" value="9780593178553"/>
# <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
# <input id="siteName" name="siteName" type="hidden" value="prh"/>
# <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
# </form>
# </div>
# </div>
# <div class="buy_clmn">
# <div class="ajax-wait hidden"></div>
# <h3>Also available from:</h3>
# <a class="btn buy hidden" rel="popover">Buy</a>
# <div class="hidden parking-lot 9780593178553 by_work amazonlast"></div>
# </div>
# </div>
# </div>
# </li>
# <li authid="12549" author="Joseph Heller" cat-data="Literary Fiction | Fiction Classics | Military Fiction" class="inner-facade no-bg-el" data-format="Hardcover" data-format-name="Hardcover" data-isbn="9780679437222" format-data="Hardcover" id="book9" imprint-data="Everyman's Library" isbn="9780679437222" ttl="Catch-22" workid="78171">
# <div class="container relative">
# <div class="list-number"><span>9</span></div>
# <div class="list-meta-wrap">
# <div class="list-meta seemoreenable">
# <div class="readdown-cover-wrap-desktop" href="/books/78171/catch-22-by-joseph-heller/">
# <div class="three-d">
# <div class="cover">
# <span class="">
# <img alt="Catch-22 Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780679437222" src=""/></span>
# <div class="cover__backcover-container">
# <img alt="Catch-22 Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780679437222" src=""/> </div>
# </div>
# </div>
# </div>
# <h2><a href="/books/78171/catch-22-by-joseph-heller/">Catch-22</a></h2>
# <h2 class="author">by Joseph Heller</h2>
# <div class="desc">If this wasn’t already required reading in your school, it’s about time you’ve read it.</div>
# <div class="readdown-cover-wrap-mobile" href="/books/78171/catch-22-by-joseph-heller/">
# <div class="three-d">
# <div class="cover">
# <span class="">
# <img alt="Catch-22 Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780679437222" src=""/></span>
# <div class="cover__backcover-container">
# <img alt="Catch-22 Book Cover Picture" class="img-responsive lazyload" data-src="https://images2.penguinrandomhouse.com/cover/9780679437222" src=""/> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="buy">
# <div class="buy_clmn buy_small">
# <h3>Hardcover<div class="buy-price">$28.00</div></h3>
# <div class="cart-bttns">
# <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
# <button type="submit">Add to cart</button>
# <input id="itemISBN" name="itemISBN" type="hidden" value="9780679437222"/>
# <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
# <input id="siteName" name="siteName" type="hidden" value="prh"/>
# <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
# </form>
# </div>
# </div>
# <div class="buy_clmn">
# <div class="ajax-wait hidden"></div>
# <h3>Also available from:</h3>
# <a class="btn buy hidden" rel="popover">Buy</a>
# <div class="hidden parking-lot 9780679437222 by_work amazonlast"></div>
# </div>
# </div>
# </div>
# </li>
# <li authid="22880" author="George Orwell" cat-data="Fiction" class="inner-facade no-bg-el" data-format="Paperback" data-format-name="Paperback" data-isbn="9780452284234" format-data="Paperback" id="book10" imprint-data="Berkley" isbn="9780452284234" ttl="1984" workid="326569">
# <div class="container relative">
# <div class="list-number"><span>10</span></div>
# <div class="list-meta-wrap">
# <div class="list-meta seemoreenable">
# <div class="readdown-cover-wrap-desktop" href="/books/326569/1984-by-george-orwell-with-a-foreword-by-thomas-pynchon/">
# <div class="three-d">
# <div class="cover">
# <span class="">
# <img alt="1984 Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780452284234" src=""/></span>
# <div class="cover__backcover-container">
# <img alt="1984 Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780452284234" src=""/> </div>
# </div>
# </div>
# </div>
# <h2><a href="/books/326569/1984-by-george-orwell-with-a-foreword-by-thomas-pynchon/">1984</a></h2>
# <h2 class="author">by George Orwell</h2>
# <div class="desc">We were pretty certain you’ve read one of the best books of all time, but in case you haven’t, now’s your chance.</div>
# <div class="readdown-cover-wrap-mobile" href="/books/326569/1984-by-george-orwell-with-a-foreword-by-thomas-pynchon/">
# <div class="three-d">
# <div class="cover">
# <span class="">
# <img alt="1984 Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780452284234" src=""/></span>
# <div class="cover__backcover-container">
# <img alt="1984 Book Cover Picture" class="img-responsive lazyload" data-src="https://images3.penguinrandomhouse.com/cover/9780452284234" src=""/> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="buy">
# <div class="buy_clmn buy_small">
# <h3>Paperback<div class="buy-price">$17.00</div></h3>
# <div class="cart-bttns">
# <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
# <button type="submit">Add to cart</button>
# <input id="itemISBN" name="itemISBN" type="hidden" value="9780452284234"/>
# <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
# <input id="siteName" name="siteName" type="hidden" value="prh"/>
# <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
# </form>
# </div>
# </div>
# <div class="buy_clmn">
# <div class="ajax-wait hidden"></div>
# <h3>Also available from:</h3>
# <a class="btn buy hidden" rel="popover">Buy</a>
# <div class="hidden parking-lot 9780452284234 by_work amazonlast"></div>
# </div>
# </div>
# </div>
# </li>
# <li authid="53251" author="Khaled Hosseini" cat-data="Literary Fiction" class="inner-facade no-bg-el" data-format="Paperback" data-format-name="Paperback" data-isbn="9781594631931" format-data="Paperback" id="book11" imprint-data="Riverhead Books" isbn="9781594631931" ttl="The Kite Runner" workid="288619">
# <div class="container relative">
# <div class="list-number"><span>11</span></div>
# <div class="list-meta-wrap">
# <div class="list-meta seemoreenable">
# <div class="readdown-cover-wrap-desktop" href="/books/288619/the-kite-runner-by-khaled-hosseini/">
# <div class="three-d">
# <div class="cover">
# <span class="deferred-view-scroll">
# <img alt="The Kite Runner Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9781594631931" src=""/></span>
# <div class="cover__backcover-container deferred-view-scroll">
# <img alt="The Kite Runner Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9781594631931" src=""/> </div>
# </div>
# </div>
# </div>
# <h2><a href="/books/288619/the-kite-runner-by-khaled-hosseini/">The Kite Runner</a></h2>
# <h2 class="author">by Khaled Hosseini</h2>
# <div class="desc"><em>The Kite Runner </em>is a 21st century classic. If you’ve read this brilliant book, read it again.</div>
# <div class="readdown-cover-wrap-mobile" href="/books/288619/the-kite-runner-by-khaled-hosseini/">
# <div class="three-d">
# <div class="cover">
# <span class="deferred-view-scroll">
# <img alt="The Kite Runner Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9781594631931" src=""/></span>
# <div class="cover__backcover-container deferred-view-scroll">
# <img alt="The Kite Runner Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9781594631931" src=""/> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="buy">
# <div class="buy_clmn buy_small">
# <h3>Paperback<div class="buy-price">$16.00</div></h3>
# <div class="cart-bttns">
# <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
# <button type="submit">Add to cart</button>
# <input id="itemISBN" name="itemISBN" type="hidden" value="9781594631931"/>
# <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
# <input id="siteName" name="siteName" type="hidden" value="prh"/>
# <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
# </form>
# </div>
# </div>
# <div class="buy_clmn">
# <div class="ajax-wait hidden"></div>
# <h3>Also available from:</h3>
# <a class="btn buy hidden" rel="popover">Buy</a>
# <div class="hidden parking-lot 9781594631931 by_work amazonlast"></div>
# </div>
# </div>
# </div>
# </li>
# <li authid="277" author="Louisa May Alcott" cat-data="Classics | Children's Middle Grade Books | Children's Picture Books" class="inner-facade no-bg-el" data-ebook="9780553904093" data-format="Paperback" data-format-name="Paperback" data-isbn="9780375756726" format-data="Paperback,Ebook,Audio" id="book12" imprint-data="Modern Library" isbn="9780375756726" ttl="Little Women" workid="1688">
# <div class="container relative">
# <div class="list-number"><span>12</span></div>
# <div class="list-meta-wrap">
# <div class="list-meta seemoreenable">
# <div class="readdown-cover-wrap-desktop" href="/books/1688/little-women-by-louisa-may-alcott/">
# <div class="three-d">
# <div class="cover">
# <span class="deferred-view-scroll">
# <img alt="Little Women Book Cover Picture" class="img-responsive" data-src="https://images4.penguinrandomhouse.com/cover/9780375756726" src=""/></span>
# <div class="cover__backcover-container deferred-view-scroll">
# <img alt="Little Women Book Cover Picture" class="img-responsive" data-src="https://images4.penguinrandomhouse.com/cover/9780375756726" src=""/> </div>
# </div>
# </div>
# </div>
# <h2><a href="/books/1688/little-women-by-louisa-may-alcott/">Little Women</a></h2>
# <h2 class="author">by Louisa May Alcott</h2>
# <div class="desc">Because you need to know Meg, Beth, Jo, and Amy.</div>
# <div class="readdown-cover-wrap-mobile" href="/books/1688/little-women-by-louisa-may-alcott/">
# <div class="three-d">
# <div class="cover">
# <span class="deferred-view-scroll">
# <img alt="Little Women Book Cover Picture" class="img-responsive" data-src="https://images4.penguinrandomhouse.com/cover/9780375756726" src=""/></span>
# <div class="cover__backcover-container deferred-view-scroll">
# <img alt="Little Women Book Cover Picture" class="img-responsive" data-src="https://images4.penguinrandomhouse.com/cover/9780375756726" src=""/> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="buy">
# <div class="buy_clmn buy_small">
# <h3>Paperback<div class="buy-price">$11.00</div></h3>
# <div class="cart-bttns">
# <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
# <button type="submit">Add to cart</button>
# <input id="itemISBN" name="itemISBN" type="hidden" value="9780375756726"/>
# <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
# <input id="siteName" name="siteName" type="hidden" value="prh"/>
# <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
# </form>
# </div>
# </div>
# <div class="buy_clmn">
# <div class="ajax-wait hidden"></div>
# <h3>Also available from:</h3>
# <a class="btn buy hidden" rel="popover">Buy</a>
# <div class="hidden parking-lot 9780375756726 by_work amazonlast"></div>
# </div>
# </div>
# </div>
# </li>
# <li authid="20870" author="David Mitchell" cat-data="Literary Fiction | Fiction Classics | Historical Fiction | Science Fiction &amp; Fantasy" class="inner-facade no-bg-el" data-ebook="9780812984422" data-format="Hardcover" data-format-name="Hardcover" data-isbn="9780812994711" format-data="Paperback,Hardcover,Ebook,Audio" id="book13" imprint-data="Modern Library" isbn="9780812994711" ttl="Cloud Atlas" workid="115430">
# <div class="container relative">
# <div class="list-number"><span>13</span></div>
# <div class="list-meta-wrap">
# <div class="list-meta seemoreenable">
# <div class="readdown-cover-wrap-desktop" href="/books/115430/cloud-atlas-by-david-mitchell/">
# <div class="three-d">
# <div class="cover">
# <span class="deferred-view-scroll">
# <img alt="Cloud Atlas Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9780812994711" src=""/></span>
# <div class="cover__backcover-container deferred-view-scroll">
# <img alt="Cloud Atlas Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9780812994711" src=""/> </div>
# </div>
# </div>
# </div>
# <h2><a href="/books/115430/cloud-atlas-by-david-mitchell/">The Cloud Atlas</a></h2>
# <h2 class="author">by David Mitchell</h2>
# <div class="desc">Another adaptation you’ll want to read to visualize in 2016.</div>
# <div class="readdown-cover-wrap-mobile" href="/books/115430/cloud-atlas-by-david-mitchell/">
# <div class="three-d">
# <div class="cover">
# <span class="deferred-view-scroll">
# <img alt="Cloud Atlas Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9780812994711" src=""/></span>
# <div class="cover__backcover-container deferred-view-scroll">
# <img alt="Cloud Atlas Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9780812994711" src=""/> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="buy">
# <div class="buy_clmn buy_small">
# <h3>Hardcover<div class="buy-price">$23.00</div></h3>
# <div class="cart-bttns">
# <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
# <button type="submit">Add to cart</button>
# <input id="itemISBN" name="itemISBN" type="hidden" value="9780812994711"/>
# <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
# <input id="siteName" name="siteName" type="hidden" value="prh"/>
# <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
# </form>
# </div>
# </div>
# <div class="buy_clmn">
# <div class="ajax-wait hidden"></div>
# <h3>Also available from:</h3>
# <a class="btn buy hidden" rel="popover">Buy</a>
# <div class="hidden parking-lot 9780812994711 by_work amazonlast"></div>
# </div>
# </div>
# </div>
# </li>
# <li authid="24886" author="Ayn Rand" cat-data="Literary Fiction" class="inner-facade no-bg-el" data-ebook="9781101137185" data-format="Hardcover" data-format-name="Hardcover" data-isbn="9780452286757" format-data="Paperback,Hardcover,Ebook" id="book14" imprint-data="NAL" isbn="9780452286757" ttl="The Fountainhead (Centennial Edition HC)" workid="532829">
# <div class="container relative">
# <div class="list-number"><span>14</span></div>
# <div class="list-meta-wrap">
# <div class="list-meta seemoreenable">
# <div class="readdown-cover-wrap-desktop" href="/books/532829/the-fountainhead-centennial-edition-hc-by-ayn-rand/">
# <div class="three-d">
# <div class="cover">
# <span class="deferred-view-scroll">
# <img alt="The Fountainhead (Centennial Edition HC) Book Cover Picture" class="img-responsive" data-src="https://images3.penguinrandomhouse.com/cover/9780452286757" src=""/></span>
# <div class="cover__backcover-container deferred-view-scroll">
# <img alt="The Fountainhead (Centennial Edition HC) Book Cover Picture" class="img-responsive" data-src="https://images3.penguinrandomhouse.com/cover/9780452286757" src=""/> </div>
# </div>
# </div>
# </div>
# <h2><a href="/books/532829/the-fountainhead-centennial-edition-hc-by-ayn-rand/">The Fountainhead</a></h2>
# <h2 class="author">by Ayn Rand</h2>
# <div class="desc">A groundbreaking novel that everyone should read at least once.</div>
# <div class="readdown-cover-wrap-mobile" href="/books/532829/the-fountainhead-centennial-edition-hc-by-ayn-rand/">
# <div class="three-d">
# <div class="cover">
# <span class="deferred-view-scroll">
# <img alt="The Fountainhead (Centennial Edition HC) Book Cover Picture" class="img-responsive" data-src="https://images3.penguinrandomhouse.com/cover/9780452286757" src=""/></span>
# <div class="cover__backcover-container deferred-view-scroll">
# <img alt="The Fountainhead (Centennial Edition HC) Book Cover Picture" class="img-responsive" data-src="https://images3.penguinrandomhouse.com/cover/9780452286757" src=""/> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="buy">
# <div class="buy_clmn buy_small">
# <h3>Hardcover<div class="buy-price">$39.95</div></h3>
# <div class="cart-bttns">
# <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
# <button type="submit">Add to cart</button>
# <input id="itemISBN" name="itemISBN" type="hidden" value="9780452286757"/>
# <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
# <input id="siteName" name="siteName" type="hidden" value="prh"/>
# <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
# </form>
# </div>
# </div>
# <div class="buy_clmn">
# <div class="ajax-wait hidden"></div>
# <h3>Also available from:</h3>
# <a class="btn buy hidden" rel="popover">Buy</a>
# <div class="hidden parking-lot 9780452286757 by_work amazonlast"></div>
# </div>
# </div>
# </div>
# </li>
# <li authid="33170,227446" author="Oscar Wilde,Coralie Bickford-Smith" cat-data="Fiction Classics | Literary Fiction | Gothic &amp; Horror" class="inner-facade no-bg-el" data-format="Hardcover" data-format-name="Hardcover" data-isbn="9780141442464" format-data="Paperback,Hardcover" id="book15" imprint-data="Penguin Classics" isbn="9780141442464" ttl="The Picture of Dorian Gray" workid="286391">
# <div class="container relative">
# <div class="list-number"><span>15</span></div>
# <div class="list-meta-wrap">
# <div class="list-meta seemoreenable">
# <div class="readdown-cover-wrap-desktop" href="/books/286391/the-picture-of-dorian-gray-by-oscar-wilde/">
# <div class="three-d">
# <div class="cover">
# <span class="deferred-view-scroll">
# <img alt="The Picture of Dorian Gray Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9780141442464" src=""/></span>
# <div class="cover__backcover-container deferred-view-scroll">
# <img alt="The Picture of Dorian Gray Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9780141442464" src=""/> </div>
# </div>
# </div>
# </div>
# <h2><a href="/books/286391/the-picture-of-dorian-gray-by-oscar-wilde/">The Picture of Dorian Gray</a></h2>
# <h2 class="author">by Oscar Wilde</h2>
# <div class="desc">For those who were deprived Oscar Wilde as required reading for school.</div>
# <div class="readdown-cover-wrap-mobile" href="/books/286391/the-picture-of-dorian-gray-by-oscar-wilde/">
# <div class="three-d">
# <div class="cover">
# <span class="deferred-view-scroll">
# <img alt="The Picture of Dorian Gray Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9780141442464" src=""/></span>
# <div class="cover__backcover-container deferred-view-scroll">
# <img alt="The Picture of Dorian Gray Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9780141442464" src=""/> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="buy">
# <div class="buy_clmn buy_small">
# <h3>Hardcover<div class="buy-price">$24.00</div></h3>
# <div class="cart-bttns">
# <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
# <button type="submit">Add to cart</button>
# <input id="itemISBN" name="itemISBN" type="hidden" value="9780141442464"/>
# <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
# <input id="siteName" name="siteName" type="hidden" value="prh"/>
# <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
# </form>
# </div>
# </div>
# <div class="buy_clmn">
# <div class="ajax-wait hidden"></div>
# <h3>Also available from:</h3>
# <a class="btn buy hidden" rel="popover">Buy</a>
# <div class="hidden parking-lot 9780141442464 by_work amazonlast"></div>
# </div>
# </div>
# </div>
# </li>
# <li authid="21729" author="Vladimir Nabokov" cat-data="Literary Fiction | Fiction Classics" class="inner-facade no-bg-el" data-ebook="9780307744029" data-format="Hardcover" data-format-name="Hardcover" data-isbn="9780679410430" format-data="Paperback,Hardcover,Ebook,Audio" id="book16" imprint-data="Everyman's Library" isbn="9780679410430" ttl="Lolita" workid="119445">
# <div class="container relative">
# <div class="list-number"><span>16</span></div>
# <div class="list-meta-wrap">
# <div class="list-meta seemoreenable">
# ...
# <div class="container relative">
# <div class="list-number"><span>17</span></div>
# <div class="list-meta-wrap">
# <div class="list-meta seemoreenable">
# <div class="readdown-cover-wrap-desktop" href="/books/303357/the-help-by-kathryn-stockett/">
# <div class="three-d">
# <div class="cover">
# <span class="deferred-view-scroll">
# <img alt="The Help Book Cover Picture" class="img-responsive" data-src="https://images3.penguinrandomhouse.com/cover/9780425232200" src=""/></span>
# <div class="cover__backcover-container deferred-view-scroll">
# <img alt="The Help Book Cover Picture" class="img-responsive" data-src="https://images3.penguinrandomhouse.com/cover/9780425232200" src=""/> </div>
# </div>
# </div>
# </div>
# <h2><a href="/books/303357/the-help-by-kathryn-stockett/">The Help</a></h2>
# <h2 class="author">by Kathryn Stockett</h2>
# <div class="desc">This powerful book is beautiful, moving, and hilarious: an essential.</div>
# <div class="readdown-cover-wrap-mobile" href="/books/303357/the-help-by-kathryn-stockett/">
# <div class="three-d">
# <div class="cover">
# <span class="deferred-view-scroll">
# <img alt="The Help Book Cover Picture" class="img-responsive" data-src="https://images3.penguinrandomhouse.com/cover/9780425232200" src=""/></span>
# <div class="cover__backcover-container deferred-view-scroll">
# <img alt="The Help Book Cover Picture" class="img-responsive" data-src="https://images3.penguinrandomhouse.com/cover/9780425232200" src=""/> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="buy">
# <div class="buy_clmn buy_small">
# <h3>Paperback<div class="buy-price">$17.00</div></h3>
# <div class="cart-bttns">
# <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
# <button type="submit">Add to cart</button>
# <input id="itemISBN" name="itemISBN" type="hidden" value="9780425232200"/>
# <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
# <input id="siteName" name="siteName" type="hidden" value="prh"/>
# <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
# </form>
# </div>
# </div>
# <div class="buy_clmn">
# <div class="ajax-wait hidden"></div>
# <h3>Also available from:</h3>
# <a class="btn buy hidden" rel="popover">Buy</a>
# <div class="hidden parking-lot 9780425232200 by_work amazonlast"></div>
# </div>
# </div>
# </div>
# </li>
# <li authid="15112" author="Mary Karr" cat-data="Arts &amp; Entertainment Biographies &amp; Memoirs | Literary Figure Biographies &amp; Memoirs | U.S. History" class="inner-facade no-bg-el" data-ebook="9781101650738" data-format="Paperback" data-format-name="Paperback" data-isbn="9780143035749" format-data="Paperback,Ebook,Audio" id="book18" imprint-data="Penguin Books" isbn="9780143035749" ttl="The Liars' Club" workid="324560">
# <div class="container relative">
# <div class="list-number"><span>18</span></div>
# <div class="list-meta-wrap">
# <div class="list-meta seemoreenable">
# <div class="readdown-cover-wrap-desktop" href="/books/324560/the-liars-club-by-mary-karr/">
# <div class="three-d">
# <div class="cover">
# <span class="deferred-view-scroll">
# <img alt="The Liars' Club Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9780143035749" src=""/></span>
# <div class="cover__backcover-container deferred-view-scroll">
# <img alt="The Liars' Club Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9780143035749" src=""/> </div>
# </div>
# </div>
# </div>
# <h2><a href="/books/324560/the-liars-club-by-mary-karr/">The Liar’s Club</a></h2>
# <h2 class="author">by Mary Karr</h2>
# <div class="desc">“The essential American story … a beauty.” —Jonathan Yardley, The Washington Post Book World</div>
# <div class="readdown-cover-wrap-mobile" href="/books/324560/the-liars-club-by-mary-karr/">
# <div class="three-d">
# <div class="cover">
# <span class="deferred-view-scroll">
# <img alt="The Liars' Club Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9780143035749" src=""/></span>
# <div class="cover__backcover-container deferred-view-scroll">
# <img alt="The Liars' Club Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9780143035749" src=""/> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="buy">
# <div class="buy_clmn buy_small">
# <h3>Paperback<div class="buy-price">$17.00</div></h3>
# <div class="cart-bttns">
# <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
# <button type="submit">Add to cart</button>
# <input id="itemISBN" name="itemISBN" type="hidden" value="9780143035749"/>
# <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
# <input id="siteName" name="siteName" type="hidden" value="prh"/>
# <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
# </form>
# </div>
# </div>
# <div class="buy_clmn">
# <div class="ajax-wait hidden"></div>
# <h3>Also available from:</h3>
# <a class="btn buy hidden" rel="popover">Buy</a>
# <div class="hidden parking-lot 9780143035749 by_work amazonlast"></div>
# </div>
# </div>
# </div>
# </li>
# <li authid="20314" author="Herman Melville" cat-data="Fiction Classics | Literary Fiction" class="inner-facade no-bg-el" data-ebook="9780553898101" data-format="Paperback" data-format-name="Paperback" data-isbn="9780679783275" format-data="Paperback,Hardcover,Ebook" id="book19" imprint-data="Modern Library" isbn="9780679783275" ttl="Moby-Dick" workid="113152">
# <div class="container relative">
# <div class="list-number"><span>19</span></div>
# <div class="list-meta-wrap">
# <div class="list-meta seemoreenable">
# <div class="readdown-cover-wrap-desktop" href="/books/113152/moby-dick-by-herman-melville/">
# <div class="three-d">
# <div class="cover">
# <span class="deferred-view-scroll">
# <img alt="Moby-Dick Book Cover Picture" class="img-responsive" data-src="https://images4.penguinrandomhouse.com/cover/9780679783275" src=""/></span>
# <div class="cover__backcover-container deferred-view-scroll">
# <img alt="Moby-Dick Book Cover Picture" class="img-responsive" data-src="https://images4.penguinrandomhouse.com/cover/9780679783275" src=""/> </div>
# </div>
# </div>
# </div>
# <h2><a href="/books/113152/moby-dick-by-herman-melville/">Moby-Dick</a></h2>
# <h2 class="author">by Herman Melville</h2>
# <div class="desc">Either you’ve read it, or you pretend you’ve read it.</div>
# <div class="readdown-cover-wrap-mobile" href="/books/113152/moby-dick-by-herman-melville/">
# <div class="three-d">
# <div class="cover">
# <span class="deferred-view-scroll">
# <img alt="Moby-Dick Book Cover Picture" class="img-responsive" data-src="https://images4.penguinrandomhouse.com/cover/9780679783275" src=""/></span>
# <div class="cover__backcover-container deferred-view-scroll">
# <img alt="Moby-Dick Book Cover Picture" class="img-responsive" data-src="https://images4.penguinrandomhouse.com/cover/9780679783275" src=""/> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="buy">
# <div class="buy_clmn buy_small">
# <h3>Paperback<div class="buy-price">$16.00</div></h3>
# <div class="cart-bttns">
# <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
# <button type="submit">Add to cart</button>
# <input id="itemISBN" name="itemISBN" type="hidden" value="9780679783275"/>
# <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
# <input id="siteName" name="siteName" type="hidden" value="prh"/>
# <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
# </form>
# </div>
# </div>
# <div class="buy_clmn">
# <div class="ajax-wait hidden"></div>
# <h3>Also available from:</h3>
# <a class="btn buy hidden" rel="popover">Buy</a>
# <div class="hidden parking-lot 9780679783275 by_work amazonlast"></div>
# </div>
# </div>
# </div>
# </li>
# <li authid="24690,20661" author="Thomas Pynchon,Frank Miller" cat-data="Literary Fiction | Fiction Classics" class="inner-facade no-bg-el" data-ebook="9781101594650" data-format="Paperback" data-format-name="Paperback" data-isbn="9780143039945" format-data="Paperback,Ebook,Audio" id="book20" imprint-data="Penguin Classics" isbn="9780143039945" ttl="Gravity's Rainbow (Classics Deluxe Edition)" workid="299800">
# <div class="container relative">
# <div class="list-number"><span>20</span></div>
# <div class="list-meta-wrap">
# <div class="list-meta seemoreenable">
# <div class="readdown-cover-wrap-desktop" href="/books/299800/gravitys-rainbow-classics-deluxe-edition-by-thomas-pynchon/">
# <div class="three-d">
# <div class="cover">
# <span class="deferred-view-scroll">
# <img alt="Gravity's Rainbow (Classics Deluxe Edition) Book Cover Picture" class="img-responsive" data-src="https://images1.penguinrandomhouse.com/cover/9780143039945" src=""/></span>
# <div class="cover__backcover-container deferred-view-scroll">
# <img alt="Gravity's Rainbow (Classics Deluxe Edition) Book Cover Picture" class="img-responsive" data-src="https://images1.penguinrandomhouse.com/cover/9780143039945" src=""/> </div>
# </div>
# </div>
# </div>
# <h2><a href="/books/299800/gravitys-rainbow-classics-deluxe-edition-by-thomas-pynchon/">Gravity’s Rainbow</a></h2>
# <h2 class="author">by Thomas Pynchon</h2>
# <div class="desc">At least one Pynchon novel should be on everyone’s TBR list.</div>
# <div class="readdown-cover-wrap-mobile" href="/books/299800/gravitys-rainbow-classics-deluxe-edition-by-thomas-pynchon/">
# <div class="three-d">
# <div class="cover">
# <span class="deferred-view-scroll">
# <img alt="Gravity's Rainbow (Classics Deluxe Edition) Book Cover Picture" class="img-responsive" data-src="https://images1.penguinrandomhouse.com/cover/9780143039945" src=""/></span>
# <div class="cover__backcover-container deferred-view-scroll">
# <img alt="Gravity's Rainbow (Classics Deluxe Edition) Book Cover Picture" class="img-responsive" data-src="https://images1.penguinrandomhouse.com/cover/9780143039945" src=""/> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="buy">
# <div class="buy_clmn buy_small">
# <h3>Paperback<div class="buy-price">$23.00</div></h3>
# <div class="cart-bttns">
# <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
# <button type="submit">Add to cart</button>
# <input id="itemISBN" name="itemISBN" type="hidden" value="9780143039945"/>
# <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
# <input id="siteName" name="siteName" type="hidden" value="prh"/>
# <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
# </form>
# </div>
# </div>
# <div class="buy_clmn">
# <div class="ajax-wait hidden"></div>
# <h3>Also available from:</h3>
# <a class="btn buy hidden" rel="popover">Buy</a>
# <div class="hidden parking-lot 9780143039945 by_work amazonlast"></div>
# </div>
# </div>
# </div>
# </li>
# <li authid="1013" author="Margaret Atwood" cat-data="Science Fiction &amp; Fantasy" class="inner-facade no-bg-el" data-format="Paperback" data-format-name="Paperback" data-isbn="9780385490818" format-data="Paperback" id="book21" imprint-data="Anchor" isbn="9780385490818" ttl="The Handmaid's Tale (Movie Tie-in)" workid="557793">
# <div class="container relative">
# <div class="list-number"><span>21</span></div>
# <div class="list-meta-wrap">
# <div class="list-meta seemoreenable">
# <div class="readdown-cover-wrap-desktop" href="/books/557793/the-handmaids-tale-movie-tie-in-by-margaret-atwood/9780385490818/">
# <div class="three-d">
# <div class="cover">
# <span class="deferred-view-scroll">
# <img alt="The Handmaid's Tale (Movie Tie-in) Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9780385490818" src=""/></span>
# <div class="cover__backcover-container deferred-view-scroll">
# <img alt="The Handmaid's Tale (Movie Tie-in) Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9780385490818" src=""/> </div>
# </div>
# </div>
# </div>
# <h2><a href="/books/557793/the-handmaids-tale-movie-tie-in-by-margaret-atwood/9780385490818/">The Handmaid’s Tale</a></h2>
# <h2 class="author">by Margaret Atwood</h2>
# <div class="desc">Same goes for Margaret Atwood, and <em>The Handmaid’s Tale </em>is definitely a classic.</div>
# <div class="readdown-cover-wrap-mobile" href="/books/557793/the-handmaids-tale-movie-tie-in-by-margaret-atwood/9780385490818/">
# <div class="three-d">
# <div class="cover">
# <span class="deferred-view-scroll">
# <img alt="The Handmaid's Tale (Movie Tie-in) Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9780385490818" src=""/></span>
# <div class="cover__backcover-container deferred-view-scroll">
# <img alt="The Handmaid's Tale (Movie Tie-in) Book Cover Picture" class="img-responsive" data-src="https://images2.penguinrandomhouse.com/cover/9780385490818" src=""/> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="buy">
# <div class="buy_clmn buy_small">
# <h3>Paperback<div class="buy-price">$15.95</div></h3>
# <div class="cart-bttns">
# <form action="https://cart.penguinrandomhouse.com/prhcart/prhcart.php" class="cart-bttn" content-type="application/x-www-form-urlencoded;charset=UTF-8" enctype="application/x-www-form-urlencoded;charset=UTF-8" method="post">
# <button type="submit">Add to cart</button>
# <input id="itemISBN" name="itemISBN" type="hidden" value="9780385490818"/>
# <input id="itemQuantity" name="itemQuantity" type="hidden" value="1"/>
# <input id="siteName" name="siteName" type="hidden" value="prh"/>
# <input id="siteReturnURL" name="siteReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="itemReturnURL" name="itemReturnURL" type="hidden" value="https://www.penguinrandomhouse.com/the-read-down/21-books-youve-been-meaning-to-read"/>
# <input id="referringSite" name="referringSite" type="hidden" value="prh"/>
# </form>
# </div>
# </div>
# <div class="buy_clmn">
# <div class="ajax-wait hidden"></div>
# <h3>Also available from:</h3>
# <a class="btn buy hidden" rel="popover">Buy</a>
# <div class="hidden parking-lot 9780385490818 by_isbn amazonlast"></div>
# </div>
# </div>
# </div>
# </li>
# </ol>

# %%
for a in soup.select('h2 a'):
    print(a.text)
# Out:
# War and Peace
# Song of Solomon
# Ulysses
# The Shadow of the Wind
# The Lord of the Rings
# The Satanic Verses
# Don Quixote
# The Golden Compass
# Catch-22
# 1984
# The Kite Runner
# Little Women
# The Cloud Atlas
# The Fountainhead
# The Picture of Dorian Gray
# Lolita
# The Help
# The Liar’s Club
# Moby-Dick
# Gravity’s Rainbow
# The Handmaid’s Tale
